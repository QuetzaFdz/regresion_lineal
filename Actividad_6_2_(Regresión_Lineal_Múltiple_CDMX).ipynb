# %% [markdown]
# <a href="https://colab.research.google.com/github/QuetzaFdz/regresion_lineal/blob/main/Actividad_6_2_(Regresi%C3%B3n_Lineal_M%C3%BAltiple_CDMX).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from turtle import color
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
mex=pd.read_csv('Mexico_limpio.csv')
mex.head()
# Out:
#                             listing_url last_scraped       source  \
# 0  https://www.airbnb.com/rooms/2056638   30/03/2023  city scrape
# 1  https://www.airbnb.com/rooms/2072354   30/03/2023  city scrape
# 2   https://www.airbnb.com/rooms/696037   29/03/2023  city scrape
# 3    https://www.airbnb.com/rooms/35797   29/03/2023  city scrape
# 4    https://www.airbnb.com/rooms/44616   30/03/2023  city scrape
#
#                                                 name  \
# 0                Amplio y luminoso loft en CoyoacÃ¡n
# 1                 Coyoacan Historic Studio Apartment
# 2  3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                        Villa Dante
# 4                                  CONDESA HAUS  B&B
#
#                                          description  \
# 0  CÃ³modo loft de dos pisos magnÃ­ficamente ubic...
# 1  This studio flat is adjacent to the owner's ho...
# 2  Beautifully decorated 3 bedroom apartment, it ...
# 3  Dentro de Villa un estudio de arte con futon, ...
# 4  A new concept of hosting in mexico through a b...
#
#                                neighborhood_overview  \
# 0                                        Sin vecinos
# 1  Located in Coyoacan, in a quiet neighborhood w...
# 2  This area is called Nuevo Polanco, it has bein...
# 3  Centro comercial Santa Fe, parque interlomas y...
# 4                                        Sin vecinos
#
#                                          picture_url  \
# 0  https://a0.muscache.com/pictures/28353712/4379...
# 1  https://a0.muscache.com/pictures/369f3371-593a...
# 2  https://a0.muscache.com/pictures/10960397/67b2...
# 3  https://a0.muscache.com/pictures/f395ab78-1185...
# 4  https://a0.muscache.com/pictures/251410/ec75fe...
#
#                                      host_url  \
# 0  https://www.airbnb.com/users/show/10531228
# 1  https://www.airbnb.com/users/show/16840050
# 2   https://www.airbnb.com/users/show/3531879
# 3    https://www.airbnb.com/users/show/153786
# 4    https://www.airbnb.com/users/show/196253
#
#                             host_name  host_since  ... review_scores_accuracy  \
# 0                               Maria  09/12/2013  ...                   4.71
# 1                             MÃ³nica  16/06/2014  ...                   4.90
# 2                    Gonzalo & Sandra  10/09/2012  ...                   4.82
# 3                                Dici  28/06/2010  ...                   4.80
# 4  Condesa Haus Bed & Breakfast  CDMX  09/08/2010  ...                   4.56
#
#   review_scores_cleanliness review_scores_checkin  \
# 0                      4.95                  5.00
# 1                      4.88                  4.93
# 2                      4.71                  4.92
# 3                      4.70                  4.80
# 4                      4.70                  4.87
#
#    review_scores_communication  review_scores_location review_scores_value  \
# 0                         4.95                    5.00                4.86
# 1                         5.00                    4.95                4.84
# 2                         4.92                    4.58                4.71
# 3                         4.80                    4.80                4.70
# 4                         4.78                    4.98                4.48
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           3
# 1                                           2
# 2                                           3
# 3                                           1
# 4                                           3
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.19
# 1                                           0              0.54
# 2                                           0              0.31
# 3                                           0              0.00
# 4                                           0              0.46
#
# [5 rows x 70 columns]

# %% [markdown]
# # **host_acceptance_rate vs host_response_rate, Price, number_of_reviews , review_scores_rating**

# %%
#Filtramos un tipo de residencia
eha1=mex[mex['room_type'] == 'Entire home/apt']
#Analizamos la dispersión de los datos indpendentes con una gráfica de diseprción
sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=eha1)
sns.scatterplot(x='price', y='host_acceptance_rate', color="red", data=eha1)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="red", data=eha1)
sns.scatterplot(x='review_scores_rating', y='host_acceptance_rate', color="yellow", data=eha1)
plt.title("\n Dispersión de variables independientes")
#Declaramos las variables dependientes e independientes
Vars_Indep= eha1[['host_response_rate', 'price','number_of_reviews','review_scores_rating']]
Var_Dep= eha1['host_acceptance_rate']
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
print('\n Modelo matemático: y= 5.96481740e-01x + -9.91646950e-08x + 2.66100781e-04x + -1.00437407e-02x + 0.38328932127145243')
model.__dict__
#Predecimos los valores del nivel de aceptación del host
y_pred= model.predict(X=eha1[['host_response_rate', 'price', 'number_of_reviews', 'review_scores_rating']])
#Insertamos la columna de predicciones
print('\n Añadimos columna de predicciones')
eha1.insert(0, 'Predicciones', y_pred)
display(eha1)
#Coeficiente de determinación
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
#Coeficiente de correlación
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
#  Modelo matemático: y= 5.96481740e-01x + -9.91646950e-08x + 2.66100781e-04x + -1.00437407e-02x + 0.38328932127145243
#
#  Añadimos columna de predicciones
#        Predicciones                                      listing_url  \
# 0          0.951656             https://www.airbnb.com/rooms/2056638
# 1          0.335610             https://www.airbnb.com/rooms/2072354
# 2          0.954603              https://www.airbnb.com/rooms/696037
# 3          0.324032               https://www.airbnb.com/rooms/35797
# 4          0.960390               https://www.airbnb.com/rooms/44616
# ...             ...                                              ...
# 24217      0.947336  https://www.airbnb.com/rooms/853790308958785669
# 24219      0.947322  https://www.airbnb.com/rooms/853923589855678923
# 24220      0.323898  https://www.airbnb.com/rooms/853966732274073000
# 24222      0.947350  https://www.airbnb.com/rooms/854247693069190865
# 24223      0.323911  https://www.airbnb.com/rooms/854260329845513725
#
#       last_scraped       source  \
# 0       30/03/2023  city scrape
# 1       30/03/2023  city scrape
# 2       29/03/2023  city scrape
# 3       29/03/2023  city scrape
# 4       30/03/2023  city scrape
# ...            ...          ...
# 24217   29/03/2023  city scrape
# 24219   30/03/2023  city scrape
# 24220   29/03/2023  city scrape
# 24222   30/03/2023  city scrape
# 24223   30/03/2023  city scrape
#
#                                                     name  \
# 0                    Amplio y luminoso loft en CoyoacÃ¡n
# 1                     Coyoacan Historic Studio Apartment
# 2      3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                            Villa Dante
# 4                                      CONDESA HAUS  B&B
# ...                                                  ...
# 24217                                          Cozy Loft
# 24219                              RincÃ³n Mexico lindo!
# 24220                     Departamento en zona diamante.
# 24222                   Espacioso y luminoso loft - Roma
# 24223      Maravilloso departamento en Ciudad de MÃ©xico
#
#                                              description  \
# 0      CÃ³modo loft de dos pisos magnÃ­ficamente ubic...
# 1      This studio flat is adjacent to the owner's ho...
# 2      Beautifully decorated 3 bedroom apartment, it ...
# 3      Dentro de Villa un estudio de arte con futon, ...
# 4      A new concept of hosting in mexico through a b...
# ...                                                  ...
# 24217          Cossy loft en una ubicaciÃ³n estratÃ©gica
# 24219  Este lugar tiene una ubicaciÃ³n estratÃ©gica: ...
# 24220  Ubicado en zona diamante, junto al aeropuerto,...
# 24222  What else does it come with?<br />- WIFI 100MB...
# 24223  Ven a descubrir este increÃ­ble departamento e...
#
#                                    neighborhood_overview  \
# 0                                            Sin vecinos
# 1      Located in Coyoacan, in a quiet neighborhood w...
# 2      This area is called Nuevo Polanco, it has bein...
# 3      Centro comercial Santa Fe, parque interlomas y...
# 4                                            Sin vecinos
# ...                                                  ...
# 24217                       En el corazÃ³n de la Condesa
# 24219                                        Sin vecinos
# 24220                                        Sin vecinos
# 24222                                        Sin vecinos
# 24223  Una zona muy bonita ya que varias de las atrac...
#
#                                              picture_url  \
# 0      https://a0.muscache.com/pictures/28353712/4379...
# 1      https://a0.muscache.com/pictures/369f3371-593a...
# 2      https://a0.muscache.com/pictures/10960397/67b2...
# 3      https://a0.muscache.com/pictures/f395ab78-1185...
# 4      https://a0.muscache.com/pictures/251410/ec75fe...
# ...                                                  ...
# 24217  https://a0.muscache.com/pictures/miso/Hosting-...
# 24219  https://a0.muscache.com/pictures/miso/Hosting-...
# 24220  https://a0.muscache.com/pictures/miso/Hosting-...
# 24222  https://a0.muscache.com/pictures/miso/Hosting-...
# 24223  https://a0.muscache.com/pictures/miso/Hosting-...
#
#                                           host_url  \
# 0       https://www.airbnb.com/users/show/10531228
# 1       https://www.airbnb.com/users/show/16840050
# 2        https://www.airbnb.com/users/show/3531879
# 3         https://www.airbnb.com/users/show/153786
# 4         https://www.airbnb.com/users/show/196253
# ...                                            ...
# 24217   https://www.airbnb.com/users/show/29239005
# 24219  https://www.airbnb.com/users/show/488030249
# 24220  https://www.airbnb.com/users/show/506816029
# 24222    https://www.airbnb.com/users/show/7799414
# 24223  https://www.airbnb.com/users/show/506864314
#
#                                 host_name  ... review_scores_accuracy  \
# 0                                   Maria  ...                   4.71
# 1                                 MÃ³nica  ...                   4.90
# 2                        Gonzalo & Sandra  ...                   4.82
# 3                                    Dici  ...                   4.80
# 4      Condesa Haus Bed & Breakfast  CDMX  ...                   4.56
# ...                                   ...  ...                    ...
# 24217                                 Sol  ...                   4.80
# 24219                                 Ana  ...                   4.80
# 24220                   Jacqueline Vivian  ...                   4.80
# 24222                               Tiane  ...                   4.80
# 24223                         Empresarial  ...                   4.80
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.95                  5.00
# 1                          4.88                  4.93
# 2                          4.71                  4.92
# 3                          4.70                  4.80
# 4                          4.70                  4.87
# ...                         ...                   ...
# 24217                      4.70                  4.80
# 24219                      4.70                  4.80
# 24220                      4.70                  4.80
# 24222                      4.70                  4.80
# 24223                      4.70                  4.80
#
#       review_scores_communication  review_scores_location  \
# 0                            4.95                    5.00
# 1                            5.00                    4.95
# 2                            4.92                    4.58
# 3                            4.80                    4.80
# 4                            4.78                    4.98
# ...                           ...                     ...
# 24217                        4.80                    4.80
# 24219                        4.80                    4.80
# 24220                        4.80                    4.80
# 24222                        4.80                    4.80
# 24223                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 0                     4.86                                           3
# 1                     4.84                                           2
# 2                     4.71                                           3
# 3                     4.70                                           1
# 4                     4.48                                           3
# ...                    ...                                         ...
# 24217                 4.70                                           3
# 24219                 4.70                                           2
# 24220                 4.70                                           1
# 24222                 4.70                                          13
# 24223                 4.70                                           2
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                2
# ...                                            ...
# 24217                                            0
# 24219                                            0
# 24220                                            0
# 24222                                            0
# 24223                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.19
# 1                                               0              0.54
# 2                                               0              0.31
# 3                                               0              0.00
# 4                                               0              0.46
# ...                                           ...               ...
# 24217                                           0              0.00
# 24219                                           0              0.00
# 24220                                           0              0.00
# 24222                                           0              0.00
# 24223                                           0              0.00
#
# [15602 rows x 71 columns]
#  Coeficiente de determinación
# 0.4816001270926624
#  Coeficiente de correlación
# 0.6939741544846338

# %%
#Filtramos un tipo de residencia
pr1=mex[mex['room_type'] == 'Private room']
#Analizamos la dispersión de los datos indpendentes con una gráfica de diseprción
sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=pr1)
sns.scatterplot(x='price', y='host_acceptance_rate', color="red", data=pr1)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="red", data=pr1)
sns.scatterplot(x='review_scores_rating', y='host_acceptance_rate', color="yellow", data=pr1)
plt.title("\n Dispersión de variables independientes")
#Declaramos las variables dependientes e independientes
Vars_Indep= pr1[['host_response_rate', 'price','number_of_reviews','review_scores_rating']]
Var_Dep= pr1['host_acceptance_rate']
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
print('\n Modelo matemático: y= 5.50194689e-01x + -2.34851063e-07x + 3.65581354e-04x + -1.84240373e-02x + 0.43914893521566933')
model.__dict__
#Predecimos los valores del nivel de aceptación del host
y_pred= model.predict(X=pr1[['host_response_rate', 'price', 'number_of_reviews', 'review_scores_rating']])
#Insertamos la columna de predicciones
print('\n Añadimos columna de predicciones')
pr1.insert(0, 'Predicciones', y_pred)
display(pr1)
#Coeficiente de determinación
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
#Coeficiente de correlación
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
#  Modelo matemático: y= 5.50194689e-01x + -2.34851063e-07x + 3.65581354e-04x + -1.84240373e-02x + 0.43914893521566933
#
#  Añadimos columna de predicciones
#        Predicciones                                      listing_url  \
# 7          0.921108               https://www.airbnb.com/rooms/61792
# 16         0.353292              https://www.airbnb.com/rooms/760912
# 17         0.359823             https://www.airbnb.com/rooms/2088218
# 18         0.351890             https://www.airbnb.com/rooms/2093036
# 21         0.902458              https://www.airbnb.com/rooms/131610
# ...             ...                                              ...
# 24200      0.352255  https://www.airbnb.com/rooms/856473895554110501
# 24213      0.352380  https://www.airbnb.com/rooms/853707681690048732
# 24215      0.902610  https://www.airbnb.com/rooms/853746847434924262
# 24218      0.352497  https://www.airbnb.com/rooms/853922041242738127
# 24221      0.352431  https://www.airbnb.com/rooms/854225071295768399
#
#       last_scraped       source  \
# 7       30/03/2023  city scrape
# 16      30/03/2023  city scrape
# 17      30/03/2023  city scrape
# 18      29/03/2023  city scrape
# 21      29/03/2023  city scrape
# ...            ...          ...
# 24200   30/03/2023  city scrape
# 24213   30/03/2023  city scrape
# 24215   29/03/2023  city scrape
# 24218   29/03/2023  city scrape
# 24221   29/03/2023  city scrape
#
#                                                   name  \
# 7      Spacious Clean Quiet room (own bath) in Condesa
# 16                 Stylish bachelor pad in La Roma, DF
# 17              Private rooms near old Coyoacan center
# 18                 Departamento 2 dormitorios x Antara
# 21                                      MARIA DEL ALMA
# ...                                                ...
# 24200                                              506
# 24213              Beautiful Sunny bedroom off Masaryk
# 24215   Room with great view & BR 1 block from Reforma
# 24218                  Excelente Ambiente 5570,835,621
# 24221           HabitaciÃ³n privada en magnÃ­fica casa
#
#                                              description  \
# 7      Located in La Condesa, one of the best neighbo...
# 16     <b>The space</b><br />If you are coming to Mex...
# 17     Hello! I have 2 private rooms for rent in a ni...
# 18     Departamento de 2 dormitorios y 1 banos comple...
# 21     <b>The space</b><br />VIVE LA EXPERIENCIA DE C...
# ...                                                  ...
# 24200  " THE BRIT " es un edificio Ãºnico en su clase...
# 24213  This cozy and sunny bedroom is the perfect pla...
# 24215  Private room in Penthouse located in the heart...
# 24218  Tu familia estarÃ¡ cerca de todo si te hospeda...
# 24221  RelÃ¡jate en este espacio muy tranquilo y eleg...
#
#                                    neighborhood_overview  \
# 7      You are going to be in one of the nicest neigh...
# 16                                           Sin vecinos
# 17     Es una zona residencial de CoyoacÃ¡n, ubicada ...
# 18     El apartamento se encuentra en una zona reside...
# 21                                           Sin vecinos
# ...                                                  ...
# 24200                                        Sin vecinos
# 24213  Polanco one of the safest and best neighborhoo...
# 24215  Many restaurant option as well as cafes and ba...
# 24218                                        Sin vecinos
# 24221                                        Sin vecinos
#
#                                              picture_url  \
# 7      https://a0.muscache.com/pictures/4c674e38-42f8...
# 16     https://a0.muscache.com/pictures/10580755/b2dc...
# 17     https://a0.muscache.com/pictures/32395878/54f6...
# 18     https://a0.muscache.com/pictures/28553895/71d5...
# 21     https://a0.muscache.com/pictures/837085/b9ed71...
# ...                                                  ...
# 24200  https://a0.muscache.com/pictures/miso/Hosting-...
# 24213  https://a0.muscache.com/pictures/miso/Hosting-...
# 24215  https://a0.muscache.com/pictures/miso/Hosting-...
# 24218  https://a0.muscache.com/pictures/d2e3ac33-c092...
# 24221  https://a0.muscache.com/pictures/db71951a-8696...
#
#                                           host_url host_name  ...  \
# 7         https://www.airbnb.com/users/show/299558   Roberto  ...
# 16       https://www.airbnb.com/users/show/3817743       Max  ...
# 17      https://www.airbnb.com/users/show/10659485   CÃ©cile  ...
# 18       https://www.airbnb.com/users/show/3083561  Federico  ...
# 21        https://www.airbnb.com/users/show/647454  Fernando  ...
# ...                                            ...       ...  ...
# 24200  https://www.airbnb.com/users/show/505303275      Ivan  ...
# 24213  https://www.airbnb.com/users/show/506768013   Mohamed  ...
# 24215   https://www.airbnb.com/users/show/68325043   Mariana  ...
# 24218  https://www.airbnb.com/users/show/506810572     Angel  ...
# 24221  https://www.airbnb.com/users/show/154670560      Aroa  ...
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 7                       4.89                       4.9                  4.92
# 16                      4.60                       4.2                  5.00
# 17                      5.00                       4.6                  5.00
# 18                      4.80                       4.7                  4.80
# 21                      4.80                       4.7                  4.80
# ...                      ...                       ...                   ...
# 24200                   4.80                       4.7                  4.80
# 24213                   4.80                       4.7                  4.80
# 24215                   4.80                       4.7                  4.80
# 24218                   4.80                       4.7                  4.80
# 24221                   4.80                       4.7                  4.80
#
#       review_scores_communication  review_scores_location  \
# 7                            4.95                    4.94
# 16                           4.60                    4.80
# 17                           4.80                    4.40
# 18                           4.80                    4.80
# 21                           4.80                    4.80
# ...                           ...                     ...
# 24200                        4.80                    4.80
# 24213                        4.80                    4.80
# 24215                        4.80                    4.80
# 24218                        4.80                    4.80
# 24221                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 7                     4.87                                           0
# 16                    4.60                                           0
# 17                    4.40                                           0
# 18                    4.70                                           0
# 21                    4.70                                           1
# ...                    ...                                         ...
# 24200                 4.70                                           1
# 24213                 4.70                                           0
# 24215                 4.70                                           0
# 24218                 4.70                                           0
# 24221                 4.70                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 7                                                2
# 16                                               1
# 17                                               1
# 18                                               1
# 21                                               2
# ...                                            ...
# 24200                                            5
# 24213                                            1
# 24215                                            1
# 24218                                            2
# 24221                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 7                                               0              0.94
# 16                                              0              0.04
# 17                                              0              0.04
# 18                                              0              0.00
# 21                                              0              0.00
# ...                                           ...               ...
# 24200                                           0              0.00
# 24213                                           0              0.00
# 24215                                           0              0.00
# 24218                                           0              0.00
# 24221                                           0              0.00
#
# [8202 rows x 71 columns]
#  Coeficiente de determinación
# 0.38642654783548913
#  Coeficiente de correlación
# 0.6216321644151701

# %% [markdown]
# # **Price vs availability_365, host_response_rate, number_of_reviews, accommodate**

# %%
#Filtramos un tipo de residencia
eha2=mex[mex['room_type'] == 'Entire home/apt']
#Analizamos la dispersión de los datos indpendentes con una gráfica de diseprción
sns.scatterplot(x='availability_365', y='price', color="blue", data=eha2)
sns.scatterplot(x='host_response_rate', y='price', color="red", data=eha2)
sns.scatterplot(x='number_of_reviews', y='price', color="red", data=eha2)
sns.scatterplot(x='accommodates', y='price', color="yellow", data=eha2)
plt.title("\n Dispersión de variables independientes")
#Declaramos las variables dependientes e independientes
Vars_Indep= eha2[['availability_365', 'host_response_rate','number_of_reviews','accommodates']]
Var_Dep= eha2['price']
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
print('\n Modelo matemático: y= 8.31134580e-01x + -1.86989424e+03x + -2.01734761e+00x + 4.03723708e+02x + 2033.3472913905466')
model.__dict__
#Predecimos los valores del nivel de aceptación del host
y_pred= model.predict(X=eha2[['availability_365', 'host_response_rate', 'number_of_reviews', 'accommodates']])
#Insertamos la columna de predicciones
print('\n Añadimos columna de predicciones')
eha2.insert(0, 'Predicciones', y_pred)
display(eha2)
#Coeficiente de determinación
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
#Coeficiente de correlación
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
#  Modelo matemático: y= 8.31134580e-01x + -1.86989424e+03x + -2.01734761e+00x + 4.03723708e+02x + 2033.3472913905466
#
#  Añadimos columna de predicciones
#        Predicciones                                      listing_url  \
# 0       1601.547477             https://www.airbnb.com/rooms/2056638
# 1       3005.309068             https://www.airbnb.com/rooms/2072354
# 2       2579.427448              https://www.airbnb.com/rooms/696037
# 3       3142.496559               https://www.airbnb.com/rooms/35797
# 4       5983.189756               https://www.airbnb.com/rooms/44616
# ...             ...                                              ...
# 24217   1255.148491  https://www.airbnb.com/rooms/853790308958785669
# 24219   1263.459837  https://www.airbnb.com/rooms/853923589855678923
# 24220   5162.777368  https://www.airbnb.com/rooms/853966732274073000
# 24222   1256.810760  https://www.airbnb.com/rooms/854247693069190865
# 24223   4754.066852  https://www.airbnb.com/rooms/854260329845513725
#
#       last_scraped       source  \
# 0       30/03/2023  city scrape
# 1       30/03/2023  city scrape
# 2       29/03/2023  city scrape
# 3       29/03/2023  city scrape
# 4       30/03/2023  city scrape
# ...            ...          ...
# 24217   29/03/2023  city scrape
# 24219   30/03/2023  city scrape
# 24220   29/03/2023  city scrape
# 24222   30/03/2023  city scrape
# 24223   30/03/2023  city scrape
#
#                                                     name  \
# 0                    Amplio y luminoso loft en CoyoacÃ¡n
# 1                     Coyoacan Historic Studio Apartment
# 2      3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                            Villa Dante
# 4                                      CONDESA HAUS  B&B
# ...                                                  ...
# 24217                                          Cozy Loft
# 24219                              RincÃ³n Mexico lindo!
# 24220                     Departamento en zona diamante.
# 24222                   Espacioso y luminoso loft - Roma
# 24223      Maravilloso departamento en Ciudad de MÃ©xico
#
#                                              description  \
# 0      CÃ³modo loft de dos pisos magnÃ­ficamente ubic...
# 1      This studio flat is adjacent to the owner's ho...
# 2      Beautifully decorated 3 bedroom apartment, it ...
# 3      Dentro de Villa un estudio de arte con futon, ...
# 4      A new concept of hosting in mexico through a b...
# ...                                                  ...
# 24217          Cossy loft en una ubicaciÃ³n estratÃ©gica
# 24219  Este lugar tiene una ubicaciÃ³n estratÃ©gica: ...
# 24220  Ubicado en zona diamante, junto al aeropuerto,...
# 24222  What else does it come with?<br />- WIFI 100MB...
# 24223  Ven a descubrir este increÃ­ble departamento e...
#
#                                    neighborhood_overview  \
# 0                                            Sin vecinos
# 1      Located in Coyoacan, in a quiet neighborhood w...
# 2      This area is called Nuevo Polanco, it has bein...
# 3      Centro comercial Santa Fe, parque interlomas y...
# 4                                            Sin vecinos
# ...                                                  ...
# 24217                       En el corazÃ³n de la Condesa
# 24219                                        Sin vecinos
# 24220                                        Sin vecinos
# 24222                                        Sin vecinos
# 24223  Una zona muy bonita ya que varias de las atrac...
#
#                                              picture_url  \
# 0      https://a0.muscache.com/pictures/28353712/4379...
# 1      https://a0.muscache.com/pictures/369f3371-593a...
# 2      https://a0.muscache.com/pictures/10960397/67b2...
# 3      https://a0.muscache.com/pictures/f395ab78-1185...
# 4      https://a0.muscache.com/pictures/251410/ec75fe...
# ...                                                  ...
# 24217  https://a0.muscache.com/pictures/miso/Hosting-...
# 24219  https://a0.muscache.com/pictures/miso/Hosting-...
# 24220  https://a0.muscache.com/pictures/miso/Hosting-...
# 24222  https://a0.muscache.com/pictures/miso/Hosting-...
# 24223  https://a0.muscache.com/pictures/miso/Hosting-...
#
#                                           host_url  \
# 0       https://www.airbnb.com/users/show/10531228
# 1       https://www.airbnb.com/users/show/16840050
# 2        https://www.airbnb.com/users/show/3531879
# 3         https://www.airbnb.com/users/show/153786
# 4         https://www.airbnb.com/users/show/196253
# ...                                            ...
# 24217   https://www.airbnb.com/users/show/29239005
# 24219  https://www.airbnb.com/users/show/488030249
# 24220  https://www.airbnb.com/users/show/506816029
# 24222    https://www.airbnb.com/users/show/7799414
# 24223  https://www.airbnb.com/users/show/506864314
#
#                                 host_name  ... review_scores_accuracy  \
# 0                                   Maria  ...                   4.71
# 1                                 MÃ³nica  ...                   4.90
# 2                        Gonzalo & Sandra  ...                   4.82
# 3                                    Dici  ...                   4.80
# 4      Condesa Haus Bed & Breakfast  CDMX  ...                   4.56
# ...                                   ...  ...                    ...
# 24217                                 Sol  ...                   4.80
# 24219                                 Ana  ...                   4.80
# 24220                   Jacqueline Vivian  ...                   4.80
# 24222                               Tiane  ...                   4.80
# 24223                         Empresarial  ...                   4.80
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.95                  5.00
# 1                          4.88                  4.93
# 2                          4.71                  4.92
# 3                          4.70                  4.80
# 4                          4.70                  4.87
# ...                         ...                   ...
# 24217                      4.70                  4.80
# 24219                      4.70                  4.80
# 24220                      4.70                  4.80
# 24222                      4.70                  4.80
# 24223                      4.70                  4.80
#
#       review_scores_communication  review_scores_location  \
# 0                            4.95                    5.00
# 1                            5.00                    4.95
# 2                            4.92                    4.58
# 3                            4.80                    4.80
# 4                            4.78                    4.98
# ...                           ...                     ...
# 24217                        4.80                    4.80
# 24219                        4.80                    4.80
# 24220                        4.80                    4.80
# 24222                        4.80                    4.80
# 24223                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 0                     4.86                                           3
# 1                     4.84                                           2
# 2                     4.71                                           3
# 3                     4.70                                           1
# 4                     4.48                                           3
# ...                    ...                                         ...
# 24217                 4.70                                           3
# 24219                 4.70                                           2
# 24220                 4.70                                           1
# 24222                 4.70                                          13
# 24223                 4.70                                           2
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                2
# ...                                            ...
# 24217                                            0
# 24219                                            0
# 24220                                            0
# 24222                                            0
# 24223                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.19
# 1                                               0              0.54
# 2                                               0              0.31
# 3                                               0              0.00
# 4                                               0              0.46
# ...                                           ...               ...
# 24217                                           0              0.00
# 24219                                           0              0.00
# 24220                                           0              0.00
# 24222                                           0              0.00
# 24223                                           0              0.00
#
# [15602 rows x 71 columns]
#  Coeficiente de determinación
# 0.005465717862114694
#  Coeficiente de correlación
# 0.0739304934523955

# %%
#Filtramos un tipo de residencia
pr2=mex[mex['room_type'] == 'Private room']
#Analizamos la dispersión de los datos indpendentes con una gráfica de diseprción
sns.scatterplot(x='availability_365', y='price', color="blue", data=pr2)
sns.scatterplot(x='host_response_rate', y='price', color="red", data=pr2)
sns.scatterplot(x='number_of_reviews', y='price', color="red", data=pr2)
sns.scatterplot(x='accommodates', y='price', color="yellow", data=pr2)
plt.title("\n Dispersión de variables independientes")
#Declaramos las variables dependientes e independientes
Vars_Indep= pr2[['availability_365', 'host_response_rate','number_of_reviews','accommodates']]
Var_Dep= pr2['price']
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
print('\n Modelo matemático: y= -1.12035625x + -992.59874793x + 2.9144699x + 298.15652833x + 1854.1566456613027')
model.__dict__
#Predecimos los valores del nivel de aceptación del host
y_pred= model.predict(X=pr2[['availability_365', 'host_response_rate', 'number_of_reviews', 'accommodates']])
#Insertamos la columna de predicciones
print('\n Añadimos columna de predicciones')
pr2.insert(0, 'Predicciones', y_pred)
display(pr2)
#Coeficiente de determinación
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
#Coeficiente de correlación
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
#  Modelo matemático: y= -1.12035625x + -992.59874793x + 2.9144699x + 298.15652833x + 1854.1566456613027
#
#  Añadimos columna de predicciones
#        Predicciones                                      listing_url  \
# 7       1450.348238               https://www.airbnb.com/rooms/61792
# 16      2058.352732              https://www.airbnb.com/rooms/760912
# 17      1848.704347             https://www.airbnb.com/rooms/2088218
# 18      2041.539670             https://www.airbnb.com/rooms/2093036
# 21      1359.279604              https://www.airbnb.com/rooms/131610
# ...             ...                                              ...
# 24200   2709.555527  https://www.airbnb.com/rooms/856473895554110501
# 24213   2253.287002  https://www.airbnb.com/rooms/853707681690048732
# 24215   1071.348047  https://www.airbnb.com/rooms/853746847434924262
# 24218   2042.660026  https://www.airbnb.com/rooms/853922041242738127
# 24221   2248.805577  https://www.airbnb.com/rooms/854225071295768399
#
#       last_scraped       source  \
# 7       30/03/2023  city scrape
# 16      30/03/2023  city scrape
# 17      30/03/2023  city scrape
# 18      29/03/2023  city scrape
# 21      29/03/2023  city scrape
# ...            ...          ...
# 24200   30/03/2023  city scrape
# 24213   30/03/2023  city scrape
# 24215   29/03/2023  city scrape
# 24218   29/03/2023  city scrape
# 24221   29/03/2023  city scrape
#
#                                                   name  \
# 7      Spacious Clean Quiet room (own bath) in Condesa
# 16                 Stylish bachelor pad in La Roma, DF
# 17              Private rooms near old Coyoacan center
# 18                 Departamento 2 dormitorios x Antara
# 21                                      MARIA DEL ALMA
# ...                                                ...
# 24200                                              506
# 24213              Beautiful Sunny bedroom off Masaryk
# 24215   Room with great view & BR 1 block from Reforma
# 24218                  Excelente Ambiente 5570,835,621
# 24221           HabitaciÃ³n privada en magnÃ­fica casa
#
#                                              description  \
# 7      Located in La Condesa, one of the best neighbo...
# 16     <b>The space</b><br />If you are coming to Mex...
# 17     Hello! I have 2 private rooms for rent in a ni...
# 18     Departamento de 2 dormitorios y 1 banos comple...
# 21     <b>The space</b><br />VIVE LA EXPERIENCIA DE C...
# ...                                                  ...
# 24200  " THE BRIT " es un edificio Ãºnico en su clase...
# 24213  This cozy and sunny bedroom is the perfect pla...
# 24215  Private room in Penthouse located in the heart...
# 24218  Tu familia estarÃ¡ cerca de todo si te hospeda...
# 24221  RelÃ¡jate en este espacio muy tranquilo y eleg...
#
#                                    neighborhood_overview  \
# 7      You are going to be in one of the nicest neigh...
# 16                                           Sin vecinos
# 17     Es una zona residencial de CoyoacÃ¡n, ubicada ...
# 18     El apartamento se encuentra en una zona reside...
# 21                                           Sin vecinos
# ...                                                  ...
# 24200                                        Sin vecinos
# 24213  Polanco one of the safest and best neighborhoo...
# 24215  Many restaurant option as well as cafes and ba...
# 24218                                        Sin vecinos
# 24221                                        Sin vecinos
#
#                                              picture_url  \
# 7      https://a0.muscache.com/pictures/4c674e38-42f8...
# 16     https://a0.muscache.com/pictures/10580755/b2dc...
# 17     https://a0.muscache.com/pictures/32395878/54f6...
# 18     https://a0.muscache.com/pictures/28553895/71d5...
# 21     https://a0.muscache.com/pictures/837085/b9ed71...
# ...                                                  ...
# 24200  https://a0.muscache.com/pictures/miso/Hosting-...
# 24213  https://a0.muscache.com/pictures/miso/Hosting-...
# 24215  https://a0.muscache.com/pictures/miso/Hosting-...
# 24218  https://a0.muscache.com/pictures/d2e3ac33-c092...
# 24221  https://a0.muscache.com/pictures/db71951a-8696...
#
#                                           host_url host_name  ...  \
# 7         https://www.airbnb.com/users/show/299558   Roberto  ...
# 16       https://www.airbnb.com/users/show/3817743       Max  ...
# 17      https://www.airbnb.com/users/show/10659485   CÃ©cile  ...
# 18       https://www.airbnb.com/users/show/3083561  Federico  ...
# 21        https://www.airbnb.com/users/show/647454  Fernando  ...
# ...                                            ...       ...  ...
# 24200  https://www.airbnb.com/users/show/505303275      Ivan  ...
# 24213  https://www.airbnb.com/users/show/506768013   Mohamed  ...
# 24215   https://www.airbnb.com/users/show/68325043   Mariana  ...
# 24218  https://www.airbnb.com/users/show/506810572     Angel  ...
# 24221  https://www.airbnb.com/users/show/154670560      Aroa  ...
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 7                       4.89                       4.9                  4.92
# 16                      4.60                       4.2                  5.00
# 17                      5.00                       4.6                  5.00
# 18                      4.80                       4.7                  4.80
# 21                      4.80                       4.7                  4.80
# ...                      ...                       ...                   ...
# 24200                   4.80                       4.7                  4.80
# 24213                   4.80                       4.7                  4.80
# 24215                   4.80                       4.7                  4.80
# 24218                   4.80                       4.7                  4.80
# 24221                   4.80                       4.7                  4.80
#
#       review_scores_communication  review_scores_location  \
# 7                            4.95                    4.94
# 16                           4.60                    4.80
# 17                           4.80                    4.40
# 18                           4.80                    4.80
# 21                           4.80                    4.80
# ...                           ...                     ...
# 24200                        4.80                    4.80
# 24213                        4.80                    4.80
# 24215                        4.80                    4.80
# 24218                        4.80                    4.80
# 24221                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 7                     4.87                                           0
# 16                    4.60                                           0
# 17                    4.40                                           0
# 18                    4.70                                           0
# 21                    4.70                                           1
# ...                    ...                                         ...
# 24200                 4.70                                           1
# 24213                 4.70                                           0
# 24215                 4.70                                           0
# 24218                 4.70                                           0
# 24221                 4.70                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 7                                                2
# 16                                               1
# 17                                               1
# 18                                               1
# 21                                               2
# ...                                            ...
# 24200                                            5
# 24213                                            1
# 24215                                            1
# 24218                                            2
# 24221                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 7                                               0              0.94
# 16                                              0              0.04
# 17                                              0              0.04
# 18                                              0              0.00
# 21                                              0              0.00
# ...                                           ...               ...
# 24200                                           0              0.00
# 24213                                           0              0.00
# 24215                                           0              0.00
# 24218                                           0              0.00
# 24221                                           0              0.00
#
# [8202 rows x 71 columns]
#  Coeficiente de determinación
# 0.0006088975110930539
#  Coeficiente de correlación
# 0.024675848741087993

# %% [markdown]
# # **host_acceptance_rate vs number_of_reviews,review_scores_cleanliness,review_scores_communication**

# %%
#Filtramos un tipo de residencia
eha3=mex[mex['room_type'] == 'Entire home/apt']
#Analizamos la dispersión de los datos indpendentes con una gráfica de diseprción
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=eha3)
sns.scatterplot(x='review_scores_cleanliness', y='host_acceptance_rate', color="red", data=eha3)
sns.scatterplot(x='review_scores_communication', y='host_acceptance_rate', color="red", data=eha3)
plt.title("\n Dispersión de variables independientes")
#Declaramos las variables dependientes e independientes
Vars_Indep= eha3[['number_of_reviews', 'review_scores_cleanliness','review_scores_communication']]
Var_Dep= eha3['host_acceptance_rate']
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
print('\n Modelo matemático: y= 0.0005621x + 0.07369308x + -0.04550103x + 0.7180969556906251')
model.__dict__
#Predecimos los valores del nivel de aceptación del host
y_pred= model.predict(X=eha3[['number_of_reviews', 'review_scores_cleanliness', 'review_scores_communication']])
#Insertamos la columna de predicciones
print('\n Añadimos columna de predicciones')
eha3.insert(0, 'Predicciones', y_pred)
display(eha3)
#Coeficiente de determinación
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
#Coeficiente de correlación
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
#  Modelo matemático: y= 0.0005621x + 0.07369308x + -0.04550103x + 0.7180969556906251
#
#  Añadimos columna de predicciones
#        Predicciones                                      listing_url  \
# 0          0.869452             https://www.airbnb.com/rooms/2056638
# 1          0.884502             https://www.airbnb.com/rooms/2072354
# 2          0.863248              https://www.airbnb.com/rooms/696037
# 3          0.846049               https://www.airbnb.com/rooms/35797
# 4          0.882934               https://www.airbnb.com/rooms/44616
# ...             ...                                              ...
# 24217      0.846049  https://www.airbnb.com/rooms/853790308958785669
# 24219      0.846049  https://www.airbnb.com/rooms/853923589855678923
# 24220      0.846049  https://www.airbnb.com/rooms/853966732274073000
# 24222      0.846049  https://www.airbnb.com/rooms/854247693069190865
# 24223      0.846049  https://www.airbnb.com/rooms/854260329845513725
#
#       last_scraped       source  \
# 0       30/03/2023  city scrape
# 1       30/03/2023  city scrape
# 2       29/03/2023  city scrape
# 3       29/03/2023  city scrape
# 4       30/03/2023  city scrape
# ...            ...          ...
# 24217   29/03/2023  city scrape
# 24219   30/03/2023  city scrape
# 24220   29/03/2023  city scrape
# 24222   30/03/2023  city scrape
# 24223   30/03/2023  city scrape
#
#                                                     name  \
# 0                    Amplio y luminoso loft en CoyoacÃ¡n
# 1                     Coyoacan Historic Studio Apartment
# 2      3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                            Villa Dante
# 4                                      CONDESA HAUS  B&B
# ...                                                  ...
# 24217                                          Cozy Loft
# 24219                              RincÃ³n Mexico lindo!
# 24220                     Departamento en zona diamante.
# 24222                   Espacioso y luminoso loft - Roma
# 24223      Maravilloso departamento en Ciudad de MÃ©xico
#
#                                              description  \
# 0      CÃ³modo loft de dos pisos magnÃ­ficamente ubic...
# 1      This studio flat is adjacent to the owner's ho...
# 2      Beautifully decorated 3 bedroom apartment, it ...
# 3      Dentro de Villa un estudio de arte con futon, ...
# 4      A new concept of hosting in mexico through a b...
# ...                                                  ...
# 24217          Cossy loft en una ubicaciÃ³n estratÃ©gica
# 24219  Este lugar tiene una ubicaciÃ³n estratÃ©gica: ...
# 24220  Ubicado en zona diamante, junto al aeropuerto,...
# 24222  What else does it come with?<br />- WIFI 100MB...
# 24223  Ven a descubrir este increÃ­ble departamento e...
#
#                                    neighborhood_overview  \
# 0                                            Sin vecinos
# 1      Located in Coyoacan, in a quiet neighborhood w...
# 2      This area is called Nuevo Polanco, it has bein...
# 3      Centro comercial Santa Fe, parque interlomas y...
# 4                                            Sin vecinos
# ...                                                  ...
# 24217                       En el corazÃ³n de la Condesa
# 24219                                        Sin vecinos
# 24220                                        Sin vecinos
# 24222                                        Sin vecinos
# 24223  Una zona muy bonita ya que varias de las atrac...
#
#                                              picture_url  \
# 0      https://a0.muscache.com/pictures/28353712/4379...
# 1      https://a0.muscache.com/pictures/369f3371-593a...
# 2      https://a0.muscache.com/pictures/10960397/67b2...
# 3      https://a0.muscache.com/pictures/f395ab78-1185...
# 4      https://a0.muscache.com/pictures/251410/ec75fe...
# ...                                                  ...
# 24217  https://a0.muscache.com/pictures/miso/Hosting-...
# 24219  https://a0.muscache.com/pictures/miso/Hosting-...
# 24220  https://a0.muscache.com/pictures/miso/Hosting-...
# 24222  https://a0.muscache.com/pictures/miso/Hosting-...
# 24223  https://a0.muscache.com/pictures/miso/Hosting-...
#
#                                           host_url  \
# 0       https://www.airbnb.com/users/show/10531228
# 1       https://www.airbnb.com/users/show/16840050
# 2        https://www.airbnb.com/users/show/3531879
# 3         https://www.airbnb.com/users/show/153786
# 4         https://www.airbnb.com/users/show/196253
# ...                                            ...
# 24217   https://www.airbnb.com/users/show/29239005
# 24219  https://www.airbnb.com/users/show/488030249
# 24220  https://www.airbnb.com/users/show/506816029
# 24222    https://www.airbnb.com/users/show/7799414
# 24223  https://www.airbnb.com/users/show/506864314
#
#                                 host_name  ... review_scores_accuracy  \
# 0                                   Maria  ...                   4.71
# 1                                 MÃ³nica  ...                   4.90
# 2                        Gonzalo & Sandra  ...                   4.82
# 3                                    Dici  ...                   4.80
# 4      Condesa Haus Bed & Breakfast  CDMX  ...                   4.56
# ...                                   ...  ...                    ...
# 24217                                 Sol  ...                   4.80
# 24219                                 Ana  ...                   4.80
# 24220                   Jacqueline Vivian  ...                   4.80
# 24222                               Tiane  ...                   4.80
# 24223                         Empresarial  ...                   4.80
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.95                  5.00
# 1                          4.88                  4.93
# 2                          4.71                  4.92
# 3                          4.70                  4.80
# 4                          4.70                  4.87
# ...                         ...                   ...
# 24217                      4.70                  4.80
# 24219                      4.70                  4.80
# 24220                      4.70                  4.80
# 24222                      4.70                  4.80
# 24223                      4.70                  4.80
#
#       review_scores_communication  review_scores_location  \
# 0                            4.95                    5.00
# 1                            5.00                    4.95
# 2                            4.92                    4.58
# 3                            4.80                    4.80
# 4                            4.78                    4.98
# ...                           ...                     ...
# 24217                        4.80                    4.80
# 24219                        4.80                    4.80
# 24220                        4.80                    4.80
# 24222                        4.80                    4.80
# 24223                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 0                     4.86                                           3
# 1                     4.84                                           2
# 2                     4.71                                           3
# 3                     4.70                                           1
# 4                     4.48                                           3
# ...                    ...                                         ...
# 24217                 4.70                                           3
# 24219                 4.70                                           2
# 24220                 4.70                                           1
# 24222                 4.70                                          13
# 24223                 4.70                                           2
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                2
# ...                                            ...
# 24217                                            0
# 24219                                            0
# 24220                                            0
# 24222                                            0
# 24223                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.19
# 1                                               0              0.54
# 2                                               0              0.31
# 3                                               0              0.00
# 4                                               0              0.46
# ...                                           ...               ...
# 24217                                           0              0.00
# 24219                                           0              0.00
# 24220                                           0              0.00
# 24222                                           0              0.00
# 24223                                           0              0.00
#
# [15602 rows x 71 columns]
#  Coeficiente de determinación
# 0.02190859506051457
#  Coeficiente de correlación
# 0.1480155230390197

# %%
#Filtramos un tipo de residencia
pr3=mex[mex['room_type'] == 'Private room']
#Analizamos la dispersión de los datos indpendentes con una gráfica de diseprción
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=pr3)
sns.scatterplot(x='review_scores_cleanliness', y='host_acceptance_rate', color="red", data=pr3)
sns.scatterplot(x='review_scores_communication', y='host_acceptance_rate', color="red", data=pr3)
plt.title("\n Dispersión de variables independientes")
#Declaramos las variables dependientes e independientes
Vars_Indep= pr3[['number_of_reviews', 'review_scores_cleanliness','review_scores_communication']]
Var_Dep= pr3['host_acceptance_rate']
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
print('\n Modelo matemático: y= 0.0005621x + 0.07369308x + -0.04550103x + 0.7180969556906251')
model.__dict__
#Predecimos los valores del nivel de aceptación del host
y_pred= model.predict(X=pr3[['number_of_reviews', 'review_scores_cleanliness', 'review_scores_communication']])
#Insertamos la columna de predicciones
print('\n Añadimos columna de predicciones')
pr3.insert(0, 'Predicciones', y_pred)
display(pr3)
#Coeficiente de determinación
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
#Coeficiente de correlación
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
#  Modelo matemático: y= 0.0005621x + 0.07369308x + -0.04550103x + 0.7180969556906251
#
#  Añadimos columna de predicciones
#        Predicciones                                      listing_url  \
# 7          0.811750               https://www.airbnb.com/rooms/61792
# 16         0.740876              https://www.airbnb.com/rooms/760912
# 17         0.748386             https://www.airbnb.com/rooms/2088218
# 18         0.746097             https://www.airbnb.com/rooms/2093036
# 21         0.746097              https://www.airbnb.com/rooms/131610
# ...             ...                                              ...
# 24200      0.746097  https://www.airbnb.com/rooms/856473895554110501
# 24213      0.746097  https://www.airbnb.com/rooms/853707681690048732
# 24215      0.746097  https://www.airbnb.com/rooms/853746847434924262
# 24218      0.746097  https://www.airbnb.com/rooms/853922041242738127
# 24221      0.746097  https://www.airbnb.com/rooms/854225071295768399
#
#       last_scraped       source  \
# 7       30/03/2023  city scrape
# 16      30/03/2023  city scrape
# 17      30/03/2023  city scrape
# 18      29/03/2023  city scrape
# 21      29/03/2023  city scrape
# ...            ...          ...
# 24200   30/03/2023  city scrape
# 24213   30/03/2023  city scrape
# 24215   29/03/2023  city scrape
# 24218   29/03/2023  city scrape
# 24221   29/03/2023  city scrape
#
#                                                   name  \
# 7      Spacious Clean Quiet room (own bath) in Condesa
# 16                 Stylish bachelor pad in La Roma, DF
# 17              Private rooms near old Coyoacan center
# 18                 Departamento 2 dormitorios x Antara
# 21                                      MARIA DEL ALMA
# ...                                                ...
# 24200                                              506
# 24213              Beautiful Sunny bedroom off Masaryk
# 24215   Room with great view & BR 1 block from Reforma
# 24218                  Excelente Ambiente 5570,835,621
# 24221           HabitaciÃ³n privada en magnÃ­fica casa
#
#                                              description  \
# 7      Located in La Condesa, one of the best neighbo...
# 16     <b>The space</b><br />If you are coming to Mex...
# 17     Hello! I have 2 private rooms for rent in a ni...
# 18     Departamento de 2 dormitorios y 1 banos comple...
# 21     <b>The space</b><br />VIVE LA EXPERIENCIA DE C...
# ...                                                  ...
# 24200  " THE BRIT " es un edificio Ãºnico en su clase...
# 24213  This cozy and sunny bedroom is the perfect pla...
# 24215  Private room in Penthouse located in the heart...
# 24218  Tu familia estarÃ¡ cerca de todo si te hospeda...
# 24221  RelÃ¡jate en este espacio muy tranquilo y eleg...
#
#                                    neighborhood_overview  \
# 7      You are going to be in one of the nicest neigh...
# 16                                           Sin vecinos
# 17     Es una zona residencial de CoyoacÃ¡n, ubicada ...
# 18     El apartamento se encuentra en una zona reside...
# 21                                           Sin vecinos
# ...                                                  ...
# 24200                                        Sin vecinos
# 24213  Polanco one of the safest and best neighborhoo...
# 24215  Many restaurant option as well as cafes and ba...
# 24218                                        Sin vecinos
# 24221                                        Sin vecinos
#
#                                              picture_url  \
# 7      https://a0.muscache.com/pictures/4c674e38-42f8...
# 16     https://a0.muscache.com/pictures/10580755/b2dc...
# 17     https://a0.muscache.com/pictures/32395878/54f6...
# 18     https://a0.muscache.com/pictures/28553895/71d5...
# 21     https://a0.muscache.com/pictures/837085/b9ed71...
# ...                                                  ...
# 24200  https://a0.muscache.com/pictures/miso/Hosting-...
# 24213  https://a0.muscache.com/pictures/miso/Hosting-...
# 24215  https://a0.muscache.com/pictures/miso/Hosting-...
# 24218  https://a0.muscache.com/pictures/d2e3ac33-c092...
# 24221  https://a0.muscache.com/pictures/db71951a-8696...
#
#                                           host_url host_name  ...  \
# 7         https://www.airbnb.com/users/show/299558   Roberto  ...
# 16       https://www.airbnb.com/users/show/3817743       Max  ...
# 17      https://www.airbnb.com/users/show/10659485   CÃ©cile  ...
# 18       https://www.airbnb.com/users/show/3083561  Federico  ...
# 21        https://www.airbnb.com/users/show/647454  Fernando  ...
# ...                                            ...       ...  ...
# 24200  https://www.airbnb.com/users/show/505303275      Ivan  ...
# 24213  https://www.airbnb.com/users/show/506768013   Mohamed  ...
# 24215   https://www.airbnb.com/users/show/68325043   Mariana  ...
# 24218  https://www.airbnb.com/users/show/506810572     Angel  ...
# 24221  https://www.airbnb.com/users/show/154670560      Aroa  ...
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 7                       4.89                       4.9                  4.92
# 16                      4.60                       4.2                  5.00
# 17                      5.00                       4.6                  5.00
# 18                      4.80                       4.7                  4.80
# 21                      4.80                       4.7                  4.80
# ...                      ...                       ...                   ...
# 24200                   4.80                       4.7                  4.80
# 24213                   4.80                       4.7                  4.80
# 24215                   4.80                       4.7                  4.80
# 24218                   4.80                       4.7                  4.80
# 24221                   4.80                       4.7                  4.80
#
#       review_scores_communication  review_scores_location  \
# 7                            4.95                    4.94
# 16                           4.60                    4.80
# 17                           4.80                    4.40
# 18                           4.80                    4.80
# 21                           4.80                    4.80
# ...                           ...                     ...
# 24200                        4.80                    4.80
# 24213                        4.80                    4.80
# 24215                        4.80                    4.80
# 24218                        4.80                    4.80
# 24221                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 7                     4.87                                           0
# 16                    4.60                                           0
# 17                    4.40                                           0
# 18                    4.70                                           0
# 21                    4.70                                           1
# ...                    ...                                         ...
# 24200                 4.70                                           1
# 24213                 4.70                                           0
# 24215                 4.70                                           0
# 24218                 4.70                                           0
# 24221                 4.70                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 7                                                2
# 16                                               1
# 17                                               1
# 18                                               1
# 21                                               2
# ...                                            ...
# 24200                                            5
# 24213                                            1
# 24215                                            1
# 24218                                            2
# 24221                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 7                                               0              0.94
# 16                                              0              0.04
# 17                                              0              0.04
# 18                                              0              0.00
# 21                                              0              0.00
# ...                                           ...               ...
# 24200                                           0              0.00
# 24213                                           0              0.00
# 24215                                           0              0.00
# 24218                                           0              0.00
# 24221                                           0              0.00
#
# [8202 rows x 71 columns]
#  Coeficiente de determinación
# 0.026226793621748734
#  Coeficiente de correlación
# 0.16194688518693015

# %% [markdown]
# # **Tabla de coeficientes de correlación y determinación**

# %%
mexn = pd.DataFrame()
print('Variables por ejemplo')
print('Ej1: host_acceptance_rate vs host_response_rate, Price, number_of_reviews , review_scores_rating')
print('Ej2: price vs availability_365, host_response_rate, number_of_reviews, accommodates')
print('Ej3: host_acceptance_rate vs number_of_reviews,review_scores_cleanliness,review_scores_communication')
ejyvar=['Ej1. Entire home/apt','Ej1. Private room','Ej2. Entire home/apt','Ej2. Private room','Ej3. Entire home/apt','Ej3. Private room']
det=[0.4816001270926624,0.38642654783548913,0.005465717862114694,0.0006088975110930539,0.02190859506051457,0.026226793621748734]
cor= [0.6939741544846338,0.6216321644151701,0.0739304934523955,0.024675848741087993,0.1480155230390197,0.16194688518693015]
mexn['Ejemplo y tipo de residencia'] = ejyvar
mexn['Determinación'] = det
mexn['Correlación'] = cor
mexn
# Out:
# Variables por ejemplo
# Ej1: host_acceptance_rate vs host_response_rate, Price, number_of_reviews , review_scores_rating
# Ej2: price vs availability_365, host_response_rate, number_of_reviews, accommodates
# Ej3: host_acceptance_rate vs number_of_reviews,review_scores_cleanliness,review_scores_communication
#   Ejemplo y tipo de residencia  Determinación  Correlación
# 0         Ej1. Entire home/apt       0.481600     0.693974
# 1            Ej1. Private room       0.386427     0.621632
# 2         Ej2. Entire home/apt       0.005466     0.073930
# 3            Ej2. Private room       0.000609     0.024676
# 4         Ej3. Entire home/apt       0.021909     0.148016
# 5            Ej3. Private room       0.026227     0.161947
