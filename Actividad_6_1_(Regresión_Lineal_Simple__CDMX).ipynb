# %% [markdown]
# <a href="https://colab.research.google.com/github/QuetzaFdz/regresion_lineal/blob/main/Actividad_6_1_(Regresi%C3%B3n_Lineal_Simple__CDMX).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from turtle import color
from sklearn.linear_model import LinearRegression

# %%
mex=pd.read_csv('Mexico_limpio.csv')

# %% [markdown]
# # **host_acceptance_rate vs host_response_rate**

# %%
eha1=mex[mex['room_type'] == 'Entire home/apt']
display(sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=eha1))
Vars_Indep= eha1[['host_response_rate']]
Var_Dep= eha1['host_acceptance_rate']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=eha1[['host_response_rate']])
display(y_pred)
print('\n Agregamos predicciones')
eha1.insert(0, 'Predicciones', y_pred)
display(eha1)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.62853051]),
#  'rank_': 1,
#  'singular_': array([39.93515671]),
#  'intercept_': 0.32772415333203697}
#  Eficiencia del modelo
# 0.4797608759218611
#  Predecimos valores
# array([0.95625466, 0.32772415, 0.95625466, ..., 0.32772415, 0.95625466,
#        0.32772415])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 0          0.956255             https://www.airbnb.com/rooms/2056638
# 1          0.327724             https://www.airbnb.com/rooms/2072354
# 2          0.956255              https://www.airbnb.com/rooms/696037
# 3          0.327724               https://www.airbnb.com/rooms/35797
# 4          0.956255               https://www.airbnb.com/rooms/44616
# ...             ...                                              ...
# 24217      0.956255  https://www.airbnb.com/rooms/853790308958785669
# 24219      0.956255  https://www.airbnb.com/rooms/853923589855678923
# 24220      0.327724  https://www.airbnb.com/rooms/853966732274073000
# 24222      0.956255  https://www.airbnb.com/rooms/854247693069190865
# 24223      0.327724  https://www.airbnb.com/rooms/854260329845513725
#
#       last_scraped       source  \
# 0       30/03/2023  city scrape
# 1       30/03/2023  city scrape
# 2       29/03/2023  city scrape
# 3       29/03/2023  city scrape
# 4       30/03/2023  city scrape
# ...            ...          ...
# 24217   29/03/2023  city scrape
# 24219   30/03/2023  city scrape
# 24220   29/03/2023  city scrape
# 24222   30/03/2023  city scrape
# 24223   30/03/2023  city scrape
#
#                                                     name  \
# 0                    Amplio y luminoso loft en CoyoacÃ¡n
# 1                     Coyoacan Historic Studio Apartment
# 2      3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                            Villa Dante
# 4                                      CONDESA HAUS  B&B
# ...                                                  ...
# 24217                                          Cozy Loft
# 24219                              RincÃ³n Mexico lindo!
# 24220                     Departamento en zona diamante.
# 24222                   Espacioso y luminoso loft - Roma
# 24223      Maravilloso departamento en Ciudad de MÃ©xico
#
#                                              description  \
# 0      CÃ³modo loft de dos pisos magnÃ­ficamente ubic...
# 1      This studio flat is adjacent to the owner's ho...
# 2      Beautifully decorated 3 bedroom apartment, it ...
# 3      Dentro de Villa un estudio de arte con futon, ...
# 4      A new concept of hosting in mexico through a b...
# ...                                                  ...
# 24217          Cossy loft en una ubicaciÃ³n estratÃ©gica
# 24219  Este lugar tiene una ubicaciÃ³n estratÃ©gica: ...
# 24220  Ubicado en zona diamante, junto al aeropuerto,...
# 24222  What else does it come with?<br />- WIFI 100MB...
# 24223  Ven a descubrir este increÃ­ble departamento e...
#
#                                    neighborhood_overview  \
# 0                                            Sin vecinos
# 1      Located in Coyoacan, in a quiet neighborhood w...
# 2      This area is called Nuevo Polanco, it has bein...
# 3      Centro comercial Santa Fe, parque interlomas y...
# 4                                            Sin vecinos
# ...                                                  ...
# 24217                       En el corazÃ³n de la Condesa
# 24219                                        Sin vecinos
# 24220                                        Sin vecinos
# 24222                                        Sin vecinos
# 24223  Una zona muy bonita ya que varias de las atrac...
#
#                                              picture_url  \
# 0      https://a0.muscache.com/pictures/28353712/4379...
# 1      https://a0.muscache.com/pictures/369f3371-593a...
# 2      https://a0.muscache.com/pictures/10960397/67b2...
# 3      https://a0.muscache.com/pictures/f395ab78-1185...
# 4      https://a0.muscache.com/pictures/251410/ec75fe...
# ...                                                  ...
# 24217  https://a0.muscache.com/pictures/miso/Hosting-...
# 24219  https://a0.muscache.com/pictures/miso/Hosting-...
# 24220  https://a0.muscache.com/pictures/miso/Hosting-...
# 24222  https://a0.muscache.com/pictures/miso/Hosting-...
# 24223  https://a0.muscache.com/pictures/miso/Hosting-...
#
#                                           host_url  \
# 0       https://www.airbnb.com/users/show/10531228
# 1       https://www.airbnb.com/users/show/16840050
# 2        https://www.airbnb.com/users/show/3531879
# 3         https://www.airbnb.com/users/show/153786
# 4         https://www.airbnb.com/users/show/196253
# ...                                            ...
# 24217   https://www.airbnb.com/users/show/29239005
# 24219  https://www.airbnb.com/users/show/488030249
# 24220  https://www.airbnb.com/users/show/506816029
# 24222    https://www.airbnb.com/users/show/7799414
# 24223  https://www.airbnb.com/users/show/506864314
#
#                                 host_name  ... review_scores_accuracy  \
# 0                                   Maria  ...                   4.71
# 1                                 MÃ³nica  ...                   4.90
# 2                        Gonzalo & Sandra  ...                   4.82
# 3                                    Dici  ...                   4.80
# 4      Condesa Haus Bed & Breakfast  CDMX  ...                   4.56
# ...                                   ...  ...                    ...
# 24217                                 Sol  ...                   4.80
# 24219                                 Ana  ...                   4.80
# 24220                   Jacqueline Vivian  ...                   4.80
# 24222                               Tiane  ...                   4.80
# 24223                         Empresarial  ...                   4.80
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.95                  5.00
# 1                          4.88                  4.93
# 2                          4.71                  4.92
# 3                          4.70                  4.80
# 4                          4.70                  4.87
# ...                         ...                   ...
# 24217                      4.70                  4.80
# 24219                      4.70                  4.80
# 24220                      4.70                  4.80
# 24222                      4.70                  4.80
# 24223                      4.70                  4.80
#
#       review_scores_communication  review_scores_location  \
# 0                            4.95                    5.00
# 1                            5.00                    4.95
# 2                            4.92                    4.58
# 3                            4.80                    4.80
# 4                            4.78                    4.98
# ...                           ...                     ...
# 24217                        4.80                    4.80
# 24219                        4.80                    4.80
# 24220                        4.80                    4.80
# 24222                        4.80                    4.80
# 24223                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 0                     4.86                                           3
# 1                     4.84                                           2
# 2                     4.71                                           3
# 3                     4.70                                           1
# 4                     4.48                                           3
# ...                    ...                                         ...
# 24217                 4.70                                           3
# 24219                 4.70                                           2
# 24220                 4.70                                           1
# 24222                 4.70                                          13
# 24223                 4.70                                           2
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                2
# ...                                            ...
# 24217                                            0
# 24219                                            0
# 24220                                            0
# 24222                                            0
# 24223                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.19
# 1                                               0              0.54
# 2                                               0              0.31
# 3                                               0              0.00
# 4                                               0              0.46
# ...                                           ...               ...
# 24217                                           0              0.00
# 24219                                           0              0.00
# 24220                                           0              0.00
# 24222                                           0              0.00
# 24223                                           0              0.00
#
# [15602 rows x 71 columns]
#  Coeficiente de determinación
# 0.4797608759218611
#  Coeficiente de correlación
# 0.6926477285907037

# %%
pr1=mex[mex['room_type'] == 'Private room']
display(sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=pr1))
Vars_Indep= pr1[['host_response_rate']]
Var_Dep= pr1['host_acceptance_rate']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=pr1[['host_response_rate']])
display(y_pred)
print('\n Agregamos predicciones')
pr1.insert(0, 'Predicciones', y_pred)
display(pr1)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.55580628]),
#  'rank_': 1,
#  'singular_': array([36.96532306]),
#  'intercept_': 0.35790933321799423}
#  Eficiencia del modelo
# 0.3824069659528213
#  Predecimos valores
# array([0.91371561, 0.35790933, 0.35790933, ..., 0.91371561, 0.35790933,
#        0.35790933])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 7          0.913716               https://www.airbnb.com/rooms/61792
# 16         0.357909              https://www.airbnb.com/rooms/760912
# 17         0.357909             https://www.airbnb.com/rooms/2088218
# 18         0.357909             https://www.airbnb.com/rooms/2093036
# 21         0.913716              https://www.airbnb.com/rooms/131610
# ...             ...                                              ...
# 24200      0.357909  https://www.airbnb.com/rooms/856473895554110501
# 24213      0.357909  https://www.airbnb.com/rooms/853707681690048732
# 24215      0.913716  https://www.airbnb.com/rooms/853746847434924262
# 24218      0.357909  https://www.airbnb.com/rooms/853922041242738127
# 24221      0.357909  https://www.airbnb.com/rooms/854225071295768399
#
#       last_scraped       source  \
# 7       30/03/2023  city scrape
# 16      30/03/2023  city scrape
# 17      30/03/2023  city scrape
# 18      29/03/2023  city scrape
# 21      29/03/2023  city scrape
# ...            ...          ...
# 24200   30/03/2023  city scrape
# 24213   30/03/2023  city scrape
# 24215   29/03/2023  city scrape
# 24218   29/03/2023  city scrape
# 24221   29/03/2023  city scrape
#
#                                                   name  \
# 7      Spacious Clean Quiet room (own bath) in Condesa
# 16                 Stylish bachelor pad in La Roma, DF
# 17              Private rooms near old Coyoacan center
# 18                 Departamento 2 dormitorios x Antara
# 21                                      MARIA DEL ALMA
# ...                                                ...
# 24200                                              506
# 24213              Beautiful Sunny bedroom off Masaryk
# 24215   Room with great view & BR 1 block from Reforma
# 24218                  Excelente Ambiente 5570,835,621
# 24221           HabitaciÃ³n privada en magnÃ­fica casa
#
#                                              description  \
# 7      Located in La Condesa, one of the best neighbo...
# 16     <b>The space</b><br />If you are coming to Mex...
# 17     Hello! I have 2 private rooms for rent in a ni...
# 18     Departamento de 2 dormitorios y 1 banos comple...
# 21     <b>The space</b><br />VIVE LA EXPERIENCIA DE C...
# ...                                                  ...
# 24200  " THE BRIT " es un edificio Ãºnico en su clase...
# 24213  This cozy and sunny bedroom is the perfect pla...
# 24215  Private room in Penthouse located in the heart...
# 24218  Tu familia estarÃ¡ cerca de todo si te hospeda...
# 24221  RelÃ¡jate en este espacio muy tranquilo y eleg...
#
#                                    neighborhood_overview  \
# 7      You are going to be in one of the nicest neigh...
# 16                                           Sin vecinos
# 17     Es una zona residencial de CoyoacÃ¡n, ubicada ...
# 18     El apartamento se encuentra en una zona reside...
# 21                                           Sin vecinos
# ...                                                  ...
# 24200                                        Sin vecinos
# 24213  Polanco one of the safest and best neighborhoo...
# 24215  Many restaurant option as well as cafes and ba...
# 24218                                        Sin vecinos
# 24221                                        Sin vecinos
#
#                                              picture_url  \
# 7      https://a0.muscache.com/pictures/4c674e38-42f8...
# 16     https://a0.muscache.com/pictures/10580755/b2dc...
# 17     https://a0.muscache.com/pictures/32395878/54f6...
# 18     https://a0.muscache.com/pictures/28553895/71d5...
# 21     https://a0.muscache.com/pictures/837085/b9ed71...
# ...                                                  ...
# 24200  https://a0.muscache.com/pictures/miso/Hosting-...
# 24213  https://a0.muscache.com/pictures/miso/Hosting-...
# 24215  https://a0.muscache.com/pictures/miso/Hosting-...
# 24218  https://a0.muscache.com/pictures/d2e3ac33-c092...
# 24221  https://a0.muscache.com/pictures/db71951a-8696...
#
#                                           host_url host_name  ...  \
# 7         https://www.airbnb.com/users/show/299558   Roberto  ...
# 16       https://www.airbnb.com/users/show/3817743       Max  ...
# 17      https://www.airbnb.com/users/show/10659485   CÃ©cile  ...
# 18       https://www.airbnb.com/users/show/3083561  Federico  ...
# 21        https://www.airbnb.com/users/show/647454  Fernando  ...
# ...                                            ...       ...  ...
# 24200  https://www.airbnb.com/users/show/505303275      Ivan  ...
# 24213  https://www.airbnb.com/users/show/506768013   Mohamed  ...
# 24215   https://www.airbnb.com/users/show/68325043   Mariana  ...
# 24218  https://www.airbnb.com/users/show/506810572     Angel  ...
# 24221  https://www.airbnb.com/users/show/154670560      Aroa  ...
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 7                       4.89                       4.9                  4.92
# 16                      4.60                       4.2                  5.00
# 17                      5.00                       4.6                  5.00
# 18                      4.80                       4.7                  4.80
# 21                      4.80                       4.7                  4.80
# ...                      ...                       ...                   ...
# 24200                   4.80                       4.7                  4.80
# 24213                   4.80                       4.7                  4.80
# 24215                   4.80                       4.7                  4.80
# 24218                   4.80                       4.7                  4.80
# 24221                   4.80                       4.7                  4.80
#
#       review_scores_communication  review_scores_location  \
# 7                            4.95                    4.94
# 16                           4.60                    4.80
# 17                           4.80                    4.40
# 18                           4.80                    4.80
# 21                           4.80                    4.80
# ...                           ...                     ...
# 24200                        4.80                    4.80
# 24213                        4.80                    4.80
# 24215                        4.80                    4.80
# 24218                        4.80                    4.80
# 24221                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 7                     4.87                                           0
# 16                    4.60                                           0
# 17                    4.40                                           0
# 18                    4.70                                           0
# 21                    4.70                                           1
# ...                    ...                                         ...
# 24200                 4.70                                           1
# 24213                 4.70                                           0
# 24215                 4.70                                           0
# 24218                 4.70                                           0
# 24221                 4.70                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 7                                                2
# 16                                               1
# 17                                               1
# 18                                               1
# 21                                               2
# ...                                            ...
# 24200                                            5
# 24213                                            1
# 24215                                            1
# 24218                                            2
# 24221                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 7                                               0              0.94
# 16                                              0              0.04
# 17                                              0              0.04
# 18                                              0              0.00
# 21                                              0              0.00
# ...                                           ...               ...
# 24200                                           0              0.00
# 24213                                           0              0.00
# 24215                                           0              0.00
# 24218                                           0              0.00
# 24221                                           0              0.00
#
# [8202 rows x 71 columns]
#  Coeficiente de determinación
# 0.3824069659528213
#  Coeficiente de correlación
# 0.6183906256993401

# %% [markdown]
# # **host_acceptance_rate vs price**

# %%
eha2=mex[mex['room_type'] == 'Entire home/apt']
display(sns.scatterplot(x='price', y='host_acceptance_rate', color="blue", data=eha2))
Vars_Indep= eha2[['price']]
Var_Dep= eha2['host_acceptance_rate']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=eha2[['price']])
display(y_pred)
print('\n Agregamos predicciones')
eha2.insert(0, 'Predicciones', y_pred)
display(eha2)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='price', ylabel='host_acceptance_rate'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['price'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-4.66993545e-07]),
#  'rank_': 1,
#  'singular_': array([1828454.89353362]),
#  'intercept_': 0.8743741305551351}
#  Eficiencia del modelo
# 0.000555202703463098
#  Predecimos valores
# array([0.87370446, 0.87398653, 0.87368812, ..., 0.8736643 , 0.87381374,
#        0.8735709 ])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 0          0.873704             https://www.airbnb.com/rooms/2056638
# 1          0.873987             https://www.airbnb.com/rooms/2072354
# 2          0.873688              https://www.airbnb.com/rooms/696037
# 3          0.872666               https://www.airbnb.com/rooms/35797
# 4          0.865968               https://www.airbnb.com/rooms/44616
# ...             ...                                              ...
# 24217      0.873916  https://www.airbnb.com/rooms/853790308958785669
# 24219      0.874019  https://www.airbnb.com/rooms/853923589855678923
# 24220      0.873664  https://www.airbnb.com/rooms/853966732274073000
# 24222      0.873814  https://www.airbnb.com/rooms/854247693069190865
# 24223      0.873571  https://www.airbnb.com/rooms/854260329845513725
#
#       last_scraped       source  \
# 0       30/03/2023  city scrape
# 1       30/03/2023  city scrape
# 2       29/03/2023  city scrape
# 3       29/03/2023  city scrape
# 4       30/03/2023  city scrape
# ...            ...          ...
# 24217   29/03/2023  city scrape
# 24219   30/03/2023  city scrape
# 24220   29/03/2023  city scrape
# 24222   30/03/2023  city scrape
# 24223   30/03/2023  city scrape
#
#                                                     name  \
# 0                    Amplio y luminoso loft en CoyoacÃ¡n
# 1                     Coyoacan Historic Studio Apartment
# 2      3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                            Villa Dante
# 4                                      CONDESA HAUS  B&B
# ...                                                  ...
# 24217                                          Cozy Loft
# 24219                              RincÃ³n Mexico lindo!
# 24220                     Departamento en zona diamante.
# 24222                   Espacioso y luminoso loft - Roma
# 24223      Maravilloso departamento en Ciudad de MÃ©xico
#
#                                              description  \
# 0      CÃ³modo loft de dos pisos magnÃ­ficamente ubic...
# 1      This studio flat is adjacent to the owner's ho...
# 2      Beautifully decorated 3 bedroom apartment, it ...
# 3      Dentro de Villa un estudio de arte con futon, ...
# 4      A new concept of hosting in mexico through a b...
# ...                                                  ...
# 24217          Cossy loft en una ubicaciÃ³n estratÃ©gica
# 24219  Este lugar tiene una ubicaciÃ³n estratÃ©gica: ...
# 24220  Ubicado en zona diamante, junto al aeropuerto,...
# 24222  What else does it come with?<br />- WIFI 100MB...
# 24223  Ven a descubrir este increÃ­ble departamento e...
#
#                                    neighborhood_overview  \
# 0                                            Sin vecinos
# 1      Located in Coyoacan, in a quiet neighborhood w...
# 2      This area is called Nuevo Polanco, it has bein...
# 3      Centro comercial Santa Fe, parque interlomas y...
# 4                                            Sin vecinos
# ...                                                  ...
# 24217                       En el corazÃ³n de la Condesa
# 24219                                        Sin vecinos
# 24220                                        Sin vecinos
# 24222                                        Sin vecinos
# 24223  Una zona muy bonita ya que varias de las atrac...
#
#                                              picture_url  \
# 0      https://a0.muscache.com/pictures/28353712/4379...
# 1      https://a0.muscache.com/pictures/369f3371-593a...
# 2      https://a0.muscache.com/pictures/10960397/67b2...
# 3      https://a0.muscache.com/pictures/f395ab78-1185...
# 4      https://a0.muscache.com/pictures/251410/ec75fe...
# ...                                                  ...
# 24217  https://a0.muscache.com/pictures/miso/Hosting-...
# 24219  https://a0.muscache.com/pictures/miso/Hosting-...
# 24220  https://a0.muscache.com/pictures/miso/Hosting-...
# 24222  https://a0.muscache.com/pictures/miso/Hosting-...
# 24223  https://a0.muscache.com/pictures/miso/Hosting-...
#
#                                           host_url  \
# 0       https://www.airbnb.com/users/show/10531228
# 1       https://www.airbnb.com/users/show/16840050
# 2        https://www.airbnb.com/users/show/3531879
# 3         https://www.airbnb.com/users/show/153786
# 4         https://www.airbnb.com/users/show/196253
# ...                                            ...
# 24217   https://www.airbnb.com/users/show/29239005
# 24219  https://www.airbnb.com/users/show/488030249
# 24220  https://www.airbnb.com/users/show/506816029
# 24222    https://www.airbnb.com/users/show/7799414
# 24223  https://www.airbnb.com/users/show/506864314
#
#                                 host_name  ... review_scores_accuracy  \
# 0                                   Maria  ...                   4.71
# 1                                 MÃ³nica  ...                   4.90
# 2                        Gonzalo & Sandra  ...                   4.82
# 3                                    Dici  ...                   4.80
# 4      Condesa Haus Bed & Breakfast  CDMX  ...                   4.56
# ...                                   ...  ...                    ...
# 24217                                 Sol  ...                   4.80
# 24219                                 Ana  ...                   4.80
# 24220                   Jacqueline Vivian  ...                   4.80
# 24222                               Tiane  ...                   4.80
# 24223                         Empresarial  ...                   4.80
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.95                  5.00
# 1                          4.88                  4.93
# 2                          4.71                  4.92
# 3                          4.70                  4.80
# 4                          4.70                  4.87
# ...                         ...                   ...
# 24217                      4.70                  4.80
# 24219                      4.70                  4.80
# 24220                      4.70                  4.80
# 24222                      4.70                  4.80
# 24223                      4.70                  4.80
#
#       review_scores_communication  review_scores_location  \
# 0                            4.95                    5.00
# 1                            5.00                    4.95
# 2                            4.92                    4.58
# 3                            4.80                    4.80
# 4                            4.78                    4.98
# ...                           ...                     ...
# 24217                        4.80                    4.80
# 24219                        4.80                    4.80
# 24220                        4.80                    4.80
# 24222                        4.80                    4.80
# 24223                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 0                     4.86                                           3
# 1                     4.84                                           2
# 2                     4.71                                           3
# 3                     4.70                                           1
# 4                     4.48                                           3
# ...                    ...                                         ...
# 24217                 4.70                                           3
# 24219                 4.70                                           2
# 24220                 4.70                                           1
# 24222                 4.70                                          13
# 24223                 4.70                                           2
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                2
# ...                                            ...
# 24217                                            0
# 24219                                            0
# 24220                                            0
# 24222                                            0
# 24223                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.19
# 1                                               0              0.54
# 2                                               0              0.31
# 3                                               0              0.00
# 4                                               0              0.46
# ...                                           ...               ...
# 24217                                           0              0.00
# 24219                                           0              0.00
# 24220                                           0              0.00
# 24222                                           0              0.00
# 24223                                           0              0.00
#
# [15602 rows x 71 columns]
#  Coeficiente de determinación
# 0.000555202703463098
#  Coeficiente de correlación
# 0.0235627397274404

# %%
pr2=mex[mex['room_type'] == 'Private room']
display(sns.scatterplot(x='price', y='host_acceptance_rate', color="blue", data=pr2))
Vars_Indep= pr2[['price']]
Var_Dep= pr2['host_acceptance_rate']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=pr2[['price']])
display(y_pred)
print('\n Agregamos predicciones')
pr2.insert(0, 'Predicciones', y_pred)
display(pr2)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='price', ylabel='host_acceptance_rate'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['price'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-3.49814314e-07]),
#  'rank_': 1,
#  'singular_': array([2160830.41606824]),
#  'intercept_': 0.7731305870565954}
#  Eficiencia del modelo
# 0.0005176144732649268
#  Predecimos valores
# array([0.77274964, 0.77287662, 0.77299941, ..., 0.7729207 , 0.77304278,
#        0.77294414])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 7          0.772750               https://www.airbnb.com/rooms/61792
# 16         0.772877              https://www.airbnb.com/rooms/760912
# 17         0.772999             https://www.airbnb.com/rooms/2088218
# 18         0.772139             https://www.airbnb.com/rooms/2093036
# 21         0.772695              https://www.airbnb.com/rooms/131610
# ...             ...                                              ...
# 24200      0.772683  https://www.airbnb.com/rooms/856473895554110501
# 24213      0.772868  https://www.airbnb.com/rooms/853707681690048732
# 24215      0.772921  https://www.airbnb.com/rooms/853746847434924262
# 24218      0.773043  https://www.airbnb.com/rooms/853922041242738127
# 24221      0.772944  https://www.airbnb.com/rooms/854225071295768399
#
#       last_scraped       source  \
# 7       30/03/2023  city scrape
# 16      30/03/2023  city scrape
# 17      30/03/2023  city scrape
# 18      29/03/2023  city scrape
# 21      29/03/2023  city scrape
# ...            ...          ...
# 24200   30/03/2023  city scrape
# 24213   30/03/2023  city scrape
# 24215   29/03/2023  city scrape
# 24218   29/03/2023  city scrape
# 24221   29/03/2023  city scrape
#
#                                                   name  \
# 7      Spacious Clean Quiet room (own bath) in Condesa
# 16                 Stylish bachelor pad in La Roma, DF
# 17              Private rooms near old Coyoacan center
# 18                 Departamento 2 dormitorios x Antara
# 21                                      MARIA DEL ALMA
# ...                                                ...
# 24200                                              506
# 24213              Beautiful Sunny bedroom off Masaryk
# 24215   Room with great view & BR 1 block from Reforma
# 24218                  Excelente Ambiente 5570,835,621
# 24221           HabitaciÃ³n privada en magnÃ­fica casa
#
#                                              description  \
# 7      Located in La Condesa, one of the best neighbo...
# 16     <b>The space</b><br />If you are coming to Mex...
# 17     Hello! I have 2 private rooms for rent in a ni...
# 18     Departamento de 2 dormitorios y 1 banos comple...
# 21     <b>The space</b><br />VIVE LA EXPERIENCIA DE C...
# ...                                                  ...
# 24200  " THE BRIT " es un edificio Ãºnico en su clase...
# 24213  This cozy and sunny bedroom is the perfect pla...
# 24215  Private room in Penthouse located in the heart...
# 24218  Tu familia estarÃ¡ cerca de todo si te hospeda...
# 24221  RelÃ¡jate en este espacio muy tranquilo y eleg...
#
#                                    neighborhood_overview  \
# 7      You are going to be in one of the nicest neigh...
# 16                                           Sin vecinos
# 17     Es una zona residencial de CoyoacÃ¡n, ubicada ...
# 18     El apartamento se encuentra en una zona reside...
# 21                                           Sin vecinos
# ...                                                  ...
# 24200                                        Sin vecinos
# 24213  Polanco one of the safest and best neighborhoo...
# 24215  Many restaurant option as well as cafes and ba...
# 24218                                        Sin vecinos
# 24221                                        Sin vecinos
#
#                                              picture_url  \
# 7      https://a0.muscache.com/pictures/4c674e38-42f8...
# 16     https://a0.muscache.com/pictures/10580755/b2dc...
# 17     https://a0.muscache.com/pictures/32395878/54f6...
# 18     https://a0.muscache.com/pictures/28553895/71d5...
# 21     https://a0.muscache.com/pictures/837085/b9ed71...
# ...                                                  ...
# 24200  https://a0.muscache.com/pictures/miso/Hosting-...
# 24213  https://a0.muscache.com/pictures/miso/Hosting-...
# 24215  https://a0.muscache.com/pictures/miso/Hosting-...
# 24218  https://a0.muscache.com/pictures/d2e3ac33-c092...
# 24221  https://a0.muscache.com/pictures/db71951a-8696...
#
#                                           host_url host_name  ...  \
# 7         https://www.airbnb.com/users/show/299558   Roberto  ...
# 16       https://www.airbnb.com/users/show/3817743       Max  ...
# 17      https://www.airbnb.com/users/show/10659485   CÃ©cile  ...
# 18       https://www.airbnb.com/users/show/3083561  Federico  ...
# 21        https://www.airbnb.com/users/show/647454  Fernando  ...
# ...                                            ...       ...  ...
# 24200  https://www.airbnb.com/users/show/505303275      Ivan  ...
# 24213  https://www.airbnb.com/users/show/506768013   Mohamed  ...
# 24215   https://www.airbnb.com/users/show/68325043   Mariana  ...
# 24218  https://www.airbnb.com/users/show/506810572     Angel  ...
# 24221  https://www.airbnb.com/users/show/154670560      Aroa  ...
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 7                       4.89                       4.9                  4.92
# 16                      4.60                       4.2                  5.00
# 17                      5.00                       4.6                  5.00
# 18                      4.80                       4.7                  4.80
# 21                      4.80                       4.7                  4.80
# ...                      ...                       ...                   ...
# 24200                   4.80                       4.7                  4.80
# 24213                   4.80                       4.7                  4.80
# 24215                   4.80                       4.7                  4.80
# 24218                   4.80                       4.7                  4.80
# 24221                   4.80                       4.7                  4.80
#
#       review_scores_communication  review_scores_location  \
# 7                            4.95                    4.94
# 16                           4.60                    4.80
# 17                           4.80                    4.40
# 18                           4.80                    4.80
# 21                           4.80                    4.80
# ...                           ...                     ...
# 24200                        4.80                    4.80
# 24213                        4.80                    4.80
# 24215                        4.80                    4.80
# 24218                        4.80                    4.80
# 24221                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 7                     4.87                                           0
# 16                    4.60                                           0
# 17                    4.40                                           0
# 18                    4.70                                           0
# 21                    4.70                                           1
# ...                    ...                                         ...
# 24200                 4.70                                           1
# 24213                 4.70                                           0
# 24215                 4.70                                           0
# 24218                 4.70                                           0
# 24221                 4.70                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 7                                                2
# 16                                               1
# 17                                               1
# 18                                               1
# 21                                               2
# ...                                            ...
# 24200                                            5
# 24213                                            1
# 24215                                            1
# 24218                                            2
# 24221                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 7                                               0              0.94
# 16                                              0              0.04
# 17                                              0              0.04
# 18                                              0              0.00
# 21                                              0              0.00
# ...                                           ...               ...
# 24200                                           0              0.00
# 24213                                           0              0.00
# 24215                                           0              0.00
# 24218                                           0              0.00
# 24221                                           0              0.00
#
# [8202 rows x 71 columns]
#  Coeficiente de determinación
# 0.0005176144732649268
#  Coeficiente de correlación
# 0.022751142240883794

# %% [markdown]
# # **host_acceptance_rate vs number_of_reviews**

# %%
eha3=mex[mex['room_type'] == 'Entire home/apt']
display(sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=eha3))
Vars_Indep= eha3[['number_of_reviews']]
Var_Dep= eha3['host_acceptance_rate']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=eha3[['number_of_reviews']])
display(y_pred)
print('\n Agregamos predicciones')
eha3.insert(0, 'Predicciones', y_pred)
display(eha3)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.00057997]),
#  'rank_': 1,
#  'singular_': array([8215.02592938]),
#  'intercept_': 0.8485223690098052}
#  Eficiencia del modelo
# 0.017285604306792823
#  Predecimos valores
# array([0.86070166, 0.88390031, 0.87114105, ..., 0.84852237, 0.84852237,
#        0.84852237])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 0          0.860702             https://www.airbnb.com/rooms/2056638
# 1          0.883900             https://www.airbnb.com/rooms/2072354
# 2          0.871141              https://www.airbnb.com/rooms/696037
# 3          0.848522               https://www.airbnb.com/rooms/35797
# 4          0.885640               https://www.airbnb.com/rooms/44616
# ...             ...                                              ...
# 24217      0.848522  https://www.airbnb.com/rooms/853790308958785669
# 24219      0.848522  https://www.airbnb.com/rooms/853923589855678923
# 24220      0.848522  https://www.airbnb.com/rooms/853966732274073000
# 24222      0.848522  https://www.airbnb.com/rooms/854247693069190865
# 24223      0.848522  https://www.airbnb.com/rooms/854260329845513725
#
#       last_scraped       source  \
# 0       30/03/2023  city scrape
# 1       30/03/2023  city scrape
# 2       29/03/2023  city scrape
# 3       29/03/2023  city scrape
# 4       30/03/2023  city scrape
# ...            ...          ...
# 24217   29/03/2023  city scrape
# 24219   30/03/2023  city scrape
# 24220   29/03/2023  city scrape
# 24222   30/03/2023  city scrape
# 24223   30/03/2023  city scrape
#
#                                                     name  \
# 0                    Amplio y luminoso loft en CoyoacÃ¡n
# 1                     Coyoacan Historic Studio Apartment
# 2      3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                            Villa Dante
# 4                                      CONDESA HAUS  B&B
# ...                                                  ...
# 24217                                          Cozy Loft
# 24219                              RincÃ³n Mexico lindo!
# 24220                     Departamento en zona diamante.
# 24222                   Espacioso y luminoso loft - Roma
# 24223      Maravilloso departamento en Ciudad de MÃ©xico
#
#                                              description  \
# 0      CÃ³modo loft de dos pisos magnÃ­ficamente ubic...
# 1      This studio flat is adjacent to the owner's ho...
# 2      Beautifully decorated 3 bedroom apartment, it ...
# 3      Dentro de Villa un estudio de arte con futon, ...
# 4      A new concept of hosting in mexico through a b...
# ...                                                  ...
# 24217          Cossy loft en una ubicaciÃ³n estratÃ©gica
# 24219  Este lugar tiene una ubicaciÃ³n estratÃ©gica: ...
# 24220  Ubicado en zona diamante, junto al aeropuerto,...
# 24222  What else does it come with?<br />- WIFI 100MB...
# 24223  Ven a descubrir este increÃ­ble departamento e...
#
#                                    neighborhood_overview  \
# 0                                            Sin vecinos
# 1      Located in Coyoacan, in a quiet neighborhood w...
# 2      This area is called Nuevo Polanco, it has bein...
# 3      Centro comercial Santa Fe, parque interlomas y...
# 4                                            Sin vecinos
# ...                                                  ...
# 24217                       En el corazÃ³n de la Condesa
# 24219                                        Sin vecinos
# 24220                                        Sin vecinos
# 24222                                        Sin vecinos
# 24223  Una zona muy bonita ya que varias de las atrac...
#
#                                              picture_url  \
# 0      https://a0.muscache.com/pictures/28353712/4379...
# 1      https://a0.muscache.com/pictures/369f3371-593a...
# 2      https://a0.muscache.com/pictures/10960397/67b2...
# 3      https://a0.muscache.com/pictures/f395ab78-1185...
# 4      https://a0.muscache.com/pictures/251410/ec75fe...
# ...                                                  ...
# 24217  https://a0.muscache.com/pictures/miso/Hosting-...
# 24219  https://a0.muscache.com/pictures/miso/Hosting-...
# 24220  https://a0.muscache.com/pictures/miso/Hosting-...
# 24222  https://a0.muscache.com/pictures/miso/Hosting-...
# 24223  https://a0.muscache.com/pictures/miso/Hosting-...
#
#                                           host_url  \
# 0       https://www.airbnb.com/users/show/10531228
# 1       https://www.airbnb.com/users/show/16840050
# 2        https://www.airbnb.com/users/show/3531879
# 3         https://www.airbnb.com/users/show/153786
# 4         https://www.airbnb.com/users/show/196253
# ...                                            ...
# 24217   https://www.airbnb.com/users/show/29239005
# 24219  https://www.airbnb.com/users/show/488030249
# 24220  https://www.airbnb.com/users/show/506816029
# 24222    https://www.airbnb.com/users/show/7799414
# 24223  https://www.airbnb.com/users/show/506864314
#
#                                 host_name  ... review_scores_accuracy  \
# 0                                   Maria  ...                   4.71
# 1                                 MÃ³nica  ...                   4.90
# 2                        Gonzalo & Sandra  ...                   4.82
# 3                                    Dici  ...                   4.80
# 4      Condesa Haus Bed & Breakfast  CDMX  ...                   4.56
# ...                                   ...  ...                    ...
# 24217                                 Sol  ...                   4.80
# 24219                                 Ana  ...                   4.80
# 24220                   Jacqueline Vivian  ...                   4.80
# 24222                               Tiane  ...                   4.80
# 24223                         Empresarial  ...                   4.80
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.95                  5.00
# 1                          4.88                  4.93
# 2                          4.71                  4.92
# 3                          4.70                  4.80
# 4                          4.70                  4.87
# ...                         ...                   ...
# 24217                      4.70                  4.80
# 24219                      4.70                  4.80
# 24220                      4.70                  4.80
# 24222                      4.70                  4.80
# 24223                      4.70                  4.80
#
#       review_scores_communication  review_scores_location  \
# 0                            4.95                    5.00
# 1                            5.00                    4.95
# 2                            4.92                    4.58
# 3                            4.80                    4.80
# 4                            4.78                    4.98
# ...                           ...                     ...
# 24217                        4.80                    4.80
# 24219                        4.80                    4.80
# 24220                        4.80                    4.80
# 24222                        4.80                    4.80
# 24223                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 0                     4.86                                           3
# 1                     4.84                                           2
# 2                     4.71                                           3
# 3                     4.70                                           1
# 4                     4.48                                           3
# ...                    ...                                         ...
# 24217                 4.70                                           3
# 24219                 4.70                                           2
# 24220                 4.70                                           1
# 24222                 4.70                                          13
# 24223                 4.70                                           2
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                2
# ...                                            ...
# 24217                                            0
# 24219                                            0
# 24220                                            0
# 24222                                            0
# 24223                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.19
# 1                                               0              0.54
# 2                                               0              0.31
# 3                                               0              0.00
# 4                                               0              0.46
# ...                                           ...               ...
# 24217                                           0              0.00
# 24219                                           0              0.00
# 24220                                           0              0.00
# 24222                                           0              0.00
# 24223                                           0              0.00
#
# [15602 rows x 71 columns]
#  Coeficiente de determinación
# 0.017285604306792823
#  Coeficiente de correlación
# 0.13147472877626645

# %%
pr3=mex[mex['room_type'] == 'Private room']
display(sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=pr3))
Vars_Indep= pr3[['number_of_reviews']]
Var_Dep= pr3['host_acceptance_rate']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=pr3[['number_of_reviews']])
display(y_pred)
print('\n Agregamos predicciones')
pr3.insert(0, 'Predicciones', y_pred)
display(pr3)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.00102198]),
#  'rank_': 1,
#  'singular_': array([5203.65954966]),
#  'intercept_': 0.7461541467021322}
#  Eficiencia del modelo
# 0.025621035420213434
#  Predecimos valores
# array([0.80951722, 0.75126407, 0.75126407, ..., 0.74615415, 0.74615415,
#        0.74615415])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 7          0.809517               https://www.airbnb.com/rooms/61792
# 16         0.751264              https://www.airbnb.com/rooms/760912
# 17         0.751264             https://www.airbnb.com/rooms/2088218
# 18         0.746154             https://www.airbnb.com/rooms/2093036
# 21         0.746154              https://www.airbnb.com/rooms/131610
# ...             ...                                              ...
# 24200      0.746154  https://www.airbnb.com/rooms/856473895554110501
# 24213      0.746154  https://www.airbnb.com/rooms/853707681690048732
# 24215      0.746154  https://www.airbnb.com/rooms/853746847434924262
# 24218      0.746154  https://www.airbnb.com/rooms/853922041242738127
# 24221      0.746154  https://www.airbnb.com/rooms/854225071295768399
#
#       last_scraped       source  \
# 7       30/03/2023  city scrape
# 16      30/03/2023  city scrape
# 17      30/03/2023  city scrape
# 18      29/03/2023  city scrape
# 21      29/03/2023  city scrape
# ...            ...          ...
# 24200   30/03/2023  city scrape
# 24213   30/03/2023  city scrape
# 24215   29/03/2023  city scrape
# 24218   29/03/2023  city scrape
# 24221   29/03/2023  city scrape
#
#                                                   name  \
# 7      Spacious Clean Quiet room (own bath) in Condesa
# 16                 Stylish bachelor pad in La Roma, DF
# 17              Private rooms near old Coyoacan center
# 18                 Departamento 2 dormitorios x Antara
# 21                                      MARIA DEL ALMA
# ...                                                ...
# 24200                                              506
# 24213              Beautiful Sunny bedroom off Masaryk
# 24215   Room with great view & BR 1 block from Reforma
# 24218                  Excelente Ambiente 5570,835,621
# 24221           HabitaciÃ³n privada en magnÃ­fica casa
#
#                                              description  \
# 7      Located in La Condesa, one of the best neighbo...
# 16     <b>The space</b><br />If you are coming to Mex...
# 17     Hello! I have 2 private rooms for rent in a ni...
# 18     Departamento de 2 dormitorios y 1 banos comple...
# 21     <b>The space</b><br />VIVE LA EXPERIENCIA DE C...
# ...                                                  ...
# 24200  " THE BRIT " es un edificio Ãºnico en su clase...
# 24213  This cozy and sunny bedroom is the perfect pla...
# 24215  Private room in Penthouse located in the heart...
# 24218  Tu familia estarÃ¡ cerca de todo si te hospeda...
# 24221  RelÃ¡jate en este espacio muy tranquilo y eleg...
#
#                                    neighborhood_overview  \
# 7      You are going to be in one of the nicest neigh...
# 16                                           Sin vecinos
# 17     Es una zona residencial de CoyoacÃ¡n, ubicada ...
# 18     El apartamento se encuentra en una zona reside...
# 21                                           Sin vecinos
# ...                                                  ...
# 24200                                        Sin vecinos
# 24213  Polanco one of the safest and best neighborhoo...
# 24215  Many restaurant option as well as cafes and ba...
# 24218                                        Sin vecinos
# 24221                                        Sin vecinos
#
#                                              picture_url  \
# 7      https://a0.muscache.com/pictures/4c674e38-42f8...
# 16     https://a0.muscache.com/pictures/10580755/b2dc...
# 17     https://a0.muscache.com/pictures/32395878/54f6...
# 18     https://a0.muscache.com/pictures/28553895/71d5...
# 21     https://a0.muscache.com/pictures/837085/b9ed71...
# ...                                                  ...
# 24200  https://a0.muscache.com/pictures/miso/Hosting-...
# 24213  https://a0.muscache.com/pictures/miso/Hosting-...
# 24215  https://a0.muscache.com/pictures/miso/Hosting-...
# 24218  https://a0.muscache.com/pictures/d2e3ac33-c092...
# 24221  https://a0.muscache.com/pictures/db71951a-8696...
#
#                                           host_url host_name  ...  \
# 7         https://www.airbnb.com/users/show/299558   Roberto  ...
# 16       https://www.airbnb.com/users/show/3817743       Max  ...
# 17      https://www.airbnb.com/users/show/10659485   CÃ©cile  ...
# 18       https://www.airbnb.com/users/show/3083561  Federico  ...
# 21        https://www.airbnb.com/users/show/647454  Fernando  ...
# ...                                            ...       ...  ...
# 24200  https://www.airbnb.com/users/show/505303275      Ivan  ...
# 24213  https://www.airbnb.com/users/show/506768013   Mohamed  ...
# 24215   https://www.airbnb.com/users/show/68325043   Mariana  ...
# 24218  https://www.airbnb.com/users/show/506810572     Angel  ...
# 24221  https://www.airbnb.com/users/show/154670560      Aroa  ...
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 7                       4.89                       4.9                  4.92
# 16                      4.60                       4.2                  5.00
# 17                      5.00                       4.6                  5.00
# 18                      4.80                       4.7                  4.80
# 21                      4.80                       4.7                  4.80
# ...                      ...                       ...                   ...
# 24200                   4.80                       4.7                  4.80
# 24213                   4.80                       4.7                  4.80
# 24215                   4.80                       4.7                  4.80
# 24218                   4.80                       4.7                  4.80
# 24221                   4.80                       4.7                  4.80
#
#       review_scores_communication  review_scores_location  \
# 7                            4.95                    4.94
# 16                           4.60                    4.80
# 17                           4.80                    4.40
# 18                           4.80                    4.80
# 21                           4.80                    4.80
# ...                           ...                     ...
# 24200                        4.80                    4.80
# 24213                        4.80                    4.80
# 24215                        4.80                    4.80
# 24218                        4.80                    4.80
# 24221                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 7                     4.87                                           0
# 16                    4.60                                           0
# 17                    4.40                                           0
# 18                    4.70                                           0
# 21                    4.70                                           1
# ...                    ...                                         ...
# 24200                 4.70                                           1
# 24213                 4.70                                           0
# 24215                 4.70                                           0
# 24218                 4.70                                           0
# 24221                 4.70                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 7                                                2
# 16                                               1
# 17                                               1
# 18                                               1
# 21                                               2
# ...                                            ...
# 24200                                            5
# 24213                                            1
# 24215                                            1
# 24218                                            2
# 24221                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 7                                               0              0.94
# 16                                              0              0.04
# 17                                              0              0.04
# 18                                              0              0.00
# 21                                              0              0.00
# ...                                           ...               ...
# 24200                                           0              0.00
# 24213                                           0              0.00
# 24215                                           0              0.00
# 24218                                           0              0.00
# 24221                                           0              0.00
#
# [8202 rows x 71 columns]
#  Coeficiente de determinación
# 0.025621035420213434
#  Coeficiente de correlación
# 0.1600657221900224

# %% [markdown]
# # **review_scores_location vs review_scores_cleanliness**

# %%
eha4=mex[mex['room_type'] == 'Entire home/apt']
display(sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=eha4))
Vars_Indep= eha4[['review_scores_cleanliness']]
Var_Dep= eha4['review_scores_location']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=eha4[['review_scores_cleanliness']])
display(y_pred)
print('\n Agregamos predicciones')
eha4.insert(0, 'Predicciones', y_pred)
display(eha4)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.43968471]),
#  'rank_': 1,
#  'singular_': array([44.59041175]),
#  'intercept_': 2.7494430858595837}
#  Eficiencia del modelo
# 0.3114701968037592
#  Predecimos valores
# array([4.92588238, 4.89510445, 4.82035805, ..., 4.81596121, 4.81596121,
#        4.81596121])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 0          4.925882             https://www.airbnb.com/rooms/2056638
# 1          4.895104             https://www.airbnb.com/rooms/2072354
# 2          4.820358              https://www.airbnb.com/rooms/696037
# 3          4.815961               https://www.airbnb.com/rooms/35797
# 4          4.815961               https://www.airbnb.com/rooms/44616
# ...             ...                                              ...
# 24217      4.815961  https://www.airbnb.com/rooms/853790308958785669
# 24219      4.815961  https://www.airbnb.com/rooms/853923589855678923
# 24220      4.815961  https://www.airbnb.com/rooms/853966732274073000
# 24222      4.815961  https://www.airbnb.com/rooms/854247693069190865
# 24223      4.815961  https://www.airbnb.com/rooms/854260329845513725
#
#       last_scraped       source  \
# 0       30/03/2023  city scrape
# 1       30/03/2023  city scrape
# 2       29/03/2023  city scrape
# 3       29/03/2023  city scrape
# 4       30/03/2023  city scrape
# ...            ...          ...
# 24217   29/03/2023  city scrape
# 24219   30/03/2023  city scrape
# 24220   29/03/2023  city scrape
# 24222   30/03/2023  city scrape
# 24223   30/03/2023  city scrape
#
#                                                     name  \
# 0                    Amplio y luminoso loft en CoyoacÃ¡n
# 1                     Coyoacan Historic Studio Apartment
# 2      3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                            Villa Dante
# 4                                      CONDESA HAUS  B&B
# ...                                                  ...
# 24217                                          Cozy Loft
# 24219                              RincÃ³n Mexico lindo!
# 24220                     Departamento en zona diamante.
# 24222                   Espacioso y luminoso loft - Roma
# 24223      Maravilloso departamento en Ciudad de MÃ©xico
#
#                                              description  \
# 0      CÃ³modo loft de dos pisos magnÃ­ficamente ubic...
# 1      This studio flat is adjacent to the owner's ho...
# 2      Beautifully decorated 3 bedroom apartment, it ...
# 3      Dentro de Villa un estudio de arte con futon, ...
# 4      A new concept of hosting in mexico through a b...
# ...                                                  ...
# 24217          Cossy loft en una ubicaciÃ³n estratÃ©gica
# 24219  Este lugar tiene una ubicaciÃ³n estratÃ©gica: ...
# 24220  Ubicado en zona diamante, junto al aeropuerto,...
# 24222  What else does it come with?<br />- WIFI 100MB...
# 24223  Ven a descubrir este increÃ­ble departamento e...
#
#                                    neighborhood_overview  \
# 0                                            Sin vecinos
# 1      Located in Coyoacan, in a quiet neighborhood w...
# 2      This area is called Nuevo Polanco, it has bein...
# 3      Centro comercial Santa Fe, parque interlomas y...
# 4                                            Sin vecinos
# ...                                                  ...
# 24217                       En el corazÃ³n de la Condesa
# 24219                                        Sin vecinos
# 24220                                        Sin vecinos
# 24222                                        Sin vecinos
# 24223  Una zona muy bonita ya que varias de las atrac...
#
#                                              picture_url  \
# 0      https://a0.muscache.com/pictures/28353712/4379...
# 1      https://a0.muscache.com/pictures/369f3371-593a...
# 2      https://a0.muscache.com/pictures/10960397/67b2...
# 3      https://a0.muscache.com/pictures/f395ab78-1185...
# 4      https://a0.muscache.com/pictures/251410/ec75fe...
# ...                                                  ...
# 24217  https://a0.muscache.com/pictures/miso/Hosting-...
# 24219  https://a0.muscache.com/pictures/miso/Hosting-...
# 24220  https://a0.muscache.com/pictures/miso/Hosting-...
# 24222  https://a0.muscache.com/pictures/miso/Hosting-...
# 24223  https://a0.muscache.com/pictures/miso/Hosting-...
#
#                                           host_url  \
# 0       https://www.airbnb.com/users/show/10531228
# 1       https://www.airbnb.com/users/show/16840050
# 2        https://www.airbnb.com/users/show/3531879
# 3         https://www.airbnb.com/users/show/153786
# 4         https://www.airbnb.com/users/show/196253
# ...                                            ...
# 24217   https://www.airbnb.com/users/show/29239005
# 24219  https://www.airbnb.com/users/show/488030249
# 24220  https://www.airbnb.com/users/show/506816029
# 24222    https://www.airbnb.com/users/show/7799414
# 24223  https://www.airbnb.com/users/show/506864314
#
#                                 host_name  ... review_scores_accuracy  \
# 0                                   Maria  ...                   4.71
# 1                                 MÃ³nica  ...                   4.90
# 2                        Gonzalo & Sandra  ...                   4.82
# 3                                    Dici  ...                   4.80
# 4      Condesa Haus Bed & Breakfast  CDMX  ...                   4.56
# ...                                   ...  ...                    ...
# 24217                                 Sol  ...                   4.80
# 24219                                 Ana  ...                   4.80
# 24220                   Jacqueline Vivian  ...                   4.80
# 24222                               Tiane  ...                   4.80
# 24223                         Empresarial  ...                   4.80
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.95                  5.00
# 1                          4.88                  4.93
# 2                          4.71                  4.92
# 3                          4.70                  4.80
# 4                          4.70                  4.87
# ...                         ...                   ...
# 24217                      4.70                  4.80
# 24219                      4.70                  4.80
# 24220                      4.70                  4.80
# 24222                      4.70                  4.80
# 24223                      4.70                  4.80
#
#       review_scores_communication  review_scores_location  \
# 0                            4.95                    5.00
# 1                            5.00                    4.95
# 2                            4.92                    4.58
# 3                            4.80                    4.80
# 4                            4.78                    4.98
# ...                           ...                     ...
# 24217                        4.80                    4.80
# 24219                        4.80                    4.80
# 24220                        4.80                    4.80
# 24222                        4.80                    4.80
# 24223                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 0                     4.86                                           3
# 1                     4.84                                           2
# 2                     4.71                                           3
# 3                     4.70                                           1
# 4                     4.48                                           3
# ...                    ...                                         ...
# 24217                 4.70                                           3
# 24219                 4.70                                           2
# 24220                 4.70                                           1
# 24222                 4.70                                          13
# 24223                 4.70                                           2
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                2
# ...                                            ...
# 24217                                            0
# 24219                                            0
# 24220                                            0
# 24222                                            0
# 24223                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.19
# 1                                               0              0.54
# 2                                               0              0.31
# 3                                               0              0.00
# 4                                               0              0.46
# ...                                           ...               ...
# 24217                                           0              0.00
# 24219                                           0              0.00
# 24220                                           0              0.00
# 24222                                           0              0.00
# 24223                                           0              0.00
#
# [15602 rows x 71 columns]
#  Coeficiente de determinación
# 0.3114701968037592
#  Coeficiente de correlación
# 0.5580951503137787

# %%
pr4=mex[mex['room_type'] == 'Private room']
display(sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=pr4))
Vars_Indep= pr4[['review_scores_cleanliness']]
Var_Dep= pr4['review_scores_location']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=pr4[['review_scores_cleanliness']])
display(y_pred)
print('\n Agregamos predicciones')
pr4.insert(0, 'Predicciones', y_pred)
display(pr4)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.65774895]),
#  'rank_': 1,
#  'singular_': array([44.81083408]),
#  'intercept_': 1.7115836796097579}
#  Eficiencia del modelo
# 0.5556849595622114
#  Predecimos valores
# array([4.93455354, 4.47412927, 4.73722885, ..., 4.80300375, 4.80300375,
#        4.80300375])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 7          4.934554               https://www.airbnb.com/rooms/61792
# 16         4.474129              https://www.airbnb.com/rooms/760912
# 17         4.737229             https://www.airbnb.com/rooms/2088218
# 18         4.803004             https://www.airbnb.com/rooms/2093036
# 21         4.803004              https://www.airbnb.com/rooms/131610
# ...             ...                                              ...
# 24200      4.803004  https://www.airbnb.com/rooms/856473895554110501
# 24213      4.803004  https://www.airbnb.com/rooms/853707681690048732
# 24215      4.803004  https://www.airbnb.com/rooms/853746847434924262
# 24218      4.803004  https://www.airbnb.com/rooms/853922041242738127
# 24221      4.803004  https://www.airbnb.com/rooms/854225071295768399
#
#       last_scraped       source  \
# 7       30/03/2023  city scrape
# 16      30/03/2023  city scrape
# 17      30/03/2023  city scrape
# 18      29/03/2023  city scrape
# 21      29/03/2023  city scrape
# ...            ...          ...
# 24200   30/03/2023  city scrape
# 24213   30/03/2023  city scrape
# 24215   29/03/2023  city scrape
# 24218   29/03/2023  city scrape
# 24221   29/03/2023  city scrape
#
#                                                   name  \
# 7      Spacious Clean Quiet room (own bath) in Condesa
# 16                 Stylish bachelor pad in La Roma, DF
# 17              Private rooms near old Coyoacan center
# 18                 Departamento 2 dormitorios x Antara
# 21                                      MARIA DEL ALMA
# ...                                                ...
# 24200                                              506
# 24213              Beautiful Sunny bedroom off Masaryk
# 24215   Room with great view & BR 1 block from Reforma
# 24218                  Excelente Ambiente 5570,835,621
# 24221           HabitaciÃ³n privada en magnÃ­fica casa
#
#                                              description  \
# 7      Located in La Condesa, one of the best neighbo...
# 16     <b>The space</b><br />If you are coming to Mex...
# 17     Hello! I have 2 private rooms for rent in a ni...
# 18     Departamento de 2 dormitorios y 1 banos comple...
# 21     <b>The space</b><br />VIVE LA EXPERIENCIA DE C...
# ...                                                  ...
# 24200  " THE BRIT " es un edificio Ãºnico en su clase...
# 24213  This cozy and sunny bedroom is the perfect pla...
# 24215  Private room in Penthouse located in the heart...
# 24218  Tu familia estarÃ¡ cerca de todo si te hospeda...
# 24221  RelÃ¡jate en este espacio muy tranquilo y eleg...
#
#                                    neighborhood_overview  \
# 7      You are going to be in one of the nicest neigh...
# 16                                           Sin vecinos
# 17     Es una zona residencial de CoyoacÃ¡n, ubicada ...
# 18     El apartamento se encuentra en una zona reside...
# 21                                           Sin vecinos
# ...                                                  ...
# 24200                                        Sin vecinos
# 24213  Polanco one of the safest and best neighborhoo...
# 24215  Many restaurant option as well as cafes and ba...
# 24218                                        Sin vecinos
# 24221                                        Sin vecinos
#
#                                              picture_url  \
# 7      https://a0.muscache.com/pictures/4c674e38-42f8...
# 16     https://a0.muscache.com/pictures/10580755/b2dc...
# 17     https://a0.muscache.com/pictures/32395878/54f6...
# 18     https://a0.muscache.com/pictures/28553895/71d5...
# 21     https://a0.muscache.com/pictures/837085/b9ed71...
# ...                                                  ...
# 24200  https://a0.muscache.com/pictures/miso/Hosting-...
# 24213  https://a0.muscache.com/pictures/miso/Hosting-...
# 24215  https://a0.muscache.com/pictures/miso/Hosting-...
# 24218  https://a0.muscache.com/pictures/d2e3ac33-c092...
# 24221  https://a0.muscache.com/pictures/db71951a-8696...
#
#                                           host_url host_name  ...  \
# 7         https://www.airbnb.com/users/show/299558   Roberto  ...
# 16       https://www.airbnb.com/users/show/3817743       Max  ...
# 17      https://www.airbnb.com/users/show/10659485   CÃ©cile  ...
# 18       https://www.airbnb.com/users/show/3083561  Federico  ...
# 21        https://www.airbnb.com/users/show/647454  Fernando  ...
# ...                                            ...       ...  ...
# 24200  https://www.airbnb.com/users/show/505303275      Ivan  ...
# 24213  https://www.airbnb.com/users/show/506768013   Mohamed  ...
# 24215   https://www.airbnb.com/users/show/68325043   Mariana  ...
# 24218  https://www.airbnb.com/users/show/506810572     Angel  ...
# 24221  https://www.airbnb.com/users/show/154670560      Aroa  ...
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 7                       4.89                       4.9                  4.92
# 16                      4.60                       4.2                  5.00
# 17                      5.00                       4.6                  5.00
# 18                      4.80                       4.7                  4.80
# 21                      4.80                       4.7                  4.80
# ...                      ...                       ...                   ...
# 24200                   4.80                       4.7                  4.80
# 24213                   4.80                       4.7                  4.80
# 24215                   4.80                       4.7                  4.80
# 24218                   4.80                       4.7                  4.80
# 24221                   4.80                       4.7                  4.80
#
#       review_scores_communication  review_scores_location  \
# 7                            4.95                    4.94
# 16                           4.60                    4.80
# 17                           4.80                    4.40
# 18                           4.80                    4.80
# 21                           4.80                    4.80
# ...                           ...                     ...
# 24200                        4.80                    4.80
# 24213                        4.80                    4.80
# 24215                        4.80                    4.80
# 24218                        4.80                    4.80
# 24221                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 7                     4.87                                           0
# 16                    4.60                                           0
# 17                    4.40                                           0
# 18                    4.70                                           0
# 21                    4.70                                           1
# ...                    ...                                         ...
# 24200                 4.70                                           1
# 24213                 4.70                                           0
# 24215                 4.70                                           0
# 24218                 4.70                                           0
# 24221                 4.70                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 7                                                2
# 16                                               1
# 17                                               1
# 18                                               1
# 21                                               2
# ...                                            ...
# 24200                                            5
# 24213                                            1
# 24215                                            1
# 24218                                            2
# 24221                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 7                                               0              0.94
# 16                                              0              0.04
# 17                                              0              0.04
# 18                                              0              0.00
# 21                                              0              0.00
# ...                                           ...               ...
# 24200                                           0              0.00
# 24213                                           0              0.00
# 24215                                           0              0.00
# 24218                                           0              0.00
# 24221                                           0              0.00
#
# [8202 rows x 71 columns]
#  Coeficiente de determinación
# 0.5556849595622114
#  Coeficiente de correlación
# 0.7454427942922324

# %% [markdown]
# # **availability_365 vs number_of_reviews**

# %%
eha5=mex[mex['room_type'] == 'Entire home/apt']
display(sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=eha5))
Vars_Indep= eha5[['number_of_reviews']]
Var_Dep= eha5['availability_365']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=eha5[['number_of_reviews']])
display(y_pred)
print('\n Agregamos predicciones')
eha5.insert(0, 'Predicciones', y_pred)
display(eha5)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.059483]),
#  'rank_': 1,
#  'singular_': array([8215.02592938]),
#  'intercept_': 243.2706349399365}
#  Eficiencia del modelo
# 0.0010085753058530766
#  Predecimos valores
# array([242.02149193, 239.6421719 , 240.95079792, ..., 243.27063494,
#        243.27063494, 243.27063494])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 0        242.021492             https://www.airbnb.com/rooms/2056638
# 1        239.642172             https://www.airbnb.com/rooms/2072354
# 2        240.950798              https://www.airbnb.com/rooms/696037
# 3        243.270635               https://www.airbnb.com/rooms/35797
# 4        239.463723               https://www.airbnb.com/rooms/44616
# ...             ...                                              ...
# 24217    243.270635  https://www.airbnb.com/rooms/853790308958785669
# 24219    243.270635  https://www.airbnb.com/rooms/853923589855678923
# 24220    243.270635  https://www.airbnb.com/rooms/853966732274073000
# 24222    243.270635  https://www.airbnb.com/rooms/854247693069190865
# 24223    243.270635  https://www.airbnb.com/rooms/854260329845513725
#
#       last_scraped       source  \
# 0       30/03/2023  city scrape
# 1       30/03/2023  city scrape
# 2       29/03/2023  city scrape
# 3       29/03/2023  city scrape
# 4       30/03/2023  city scrape
# ...            ...          ...
# 24217   29/03/2023  city scrape
# 24219   30/03/2023  city scrape
# 24220   29/03/2023  city scrape
# 24222   30/03/2023  city scrape
# 24223   30/03/2023  city scrape
#
#                                                     name  \
# 0                    Amplio y luminoso loft en CoyoacÃ¡n
# 1                     Coyoacan Historic Studio Apartment
# 2      3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                            Villa Dante
# 4                                      CONDESA HAUS  B&B
# ...                                                  ...
# 24217                                          Cozy Loft
# 24219                              RincÃ³n Mexico lindo!
# 24220                     Departamento en zona diamante.
# 24222                   Espacioso y luminoso loft - Roma
# 24223      Maravilloso departamento en Ciudad de MÃ©xico
#
#                                              description  \
# 0      CÃ³modo loft de dos pisos magnÃ­ficamente ubic...
# 1      This studio flat is adjacent to the owner's ho...
# 2      Beautifully decorated 3 bedroom apartment, it ...
# 3      Dentro de Villa un estudio de arte con futon, ...
# 4      A new concept of hosting in mexico through a b...
# ...                                                  ...
# 24217          Cossy loft en una ubicaciÃ³n estratÃ©gica
# 24219  Este lugar tiene una ubicaciÃ³n estratÃ©gica: ...
# 24220  Ubicado en zona diamante, junto al aeropuerto,...
# 24222  What else does it come with?<br />- WIFI 100MB...
# 24223  Ven a descubrir este increÃ­ble departamento e...
#
#                                    neighborhood_overview  \
# 0                                            Sin vecinos
# 1      Located in Coyoacan, in a quiet neighborhood w...
# 2      This area is called Nuevo Polanco, it has bein...
# 3      Centro comercial Santa Fe, parque interlomas y...
# 4                                            Sin vecinos
# ...                                                  ...
# 24217                       En el corazÃ³n de la Condesa
# 24219                                        Sin vecinos
# 24220                                        Sin vecinos
# 24222                                        Sin vecinos
# 24223  Una zona muy bonita ya que varias de las atrac...
#
#                                              picture_url  \
# 0      https://a0.muscache.com/pictures/28353712/4379...
# 1      https://a0.muscache.com/pictures/369f3371-593a...
# 2      https://a0.muscache.com/pictures/10960397/67b2...
# 3      https://a0.muscache.com/pictures/f395ab78-1185...
# 4      https://a0.muscache.com/pictures/251410/ec75fe...
# ...                                                  ...
# 24217  https://a0.muscache.com/pictures/miso/Hosting-...
# 24219  https://a0.muscache.com/pictures/miso/Hosting-...
# 24220  https://a0.muscache.com/pictures/miso/Hosting-...
# 24222  https://a0.muscache.com/pictures/miso/Hosting-...
# 24223  https://a0.muscache.com/pictures/miso/Hosting-...
#
#                                           host_url  \
# 0       https://www.airbnb.com/users/show/10531228
# 1       https://www.airbnb.com/users/show/16840050
# 2        https://www.airbnb.com/users/show/3531879
# 3         https://www.airbnb.com/users/show/153786
# 4         https://www.airbnb.com/users/show/196253
# ...                                            ...
# 24217   https://www.airbnb.com/users/show/29239005
# 24219  https://www.airbnb.com/users/show/488030249
# 24220  https://www.airbnb.com/users/show/506816029
# 24222    https://www.airbnb.com/users/show/7799414
# 24223  https://www.airbnb.com/users/show/506864314
#
#                                 host_name  ... review_scores_accuracy  \
# 0                                   Maria  ...                   4.71
# 1                                 MÃ³nica  ...                   4.90
# 2                        Gonzalo & Sandra  ...                   4.82
# 3                                    Dici  ...                   4.80
# 4      Condesa Haus Bed & Breakfast  CDMX  ...                   4.56
# ...                                   ...  ...                    ...
# 24217                                 Sol  ...                   4.80
# 24219                                 Ana  ...                   4.80
# 24220                   Jacqueline Vivian  ...                   4.80
# 24222                               Tiane  ...                   4.80
# 24223                         Empresarial  ...                   4.80
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.95                  5.00
# 1                          4.88                  4.93
# 2                          4.71                  4.92
# 3                          4.70                  4.80
# 4                          4.70                  4.87
# ...                         ...                   ...
# 24217                      4.70                  4.80
# 24219                      4.70                  4.80
# 24220                      4.70                  4.80
# 24222                      4.70                  4.80
# 24223                      4.70                  4.80
#
#       review_scores_communication  review_scores_location  \
# 0                            4.95                    5.00
# 1                            5.00                    4.95
# 2                            4.92                    4.58
# 3                            4.80                    4.80
# 4                            4.78                    4.98
# ...                           ...                     ...
# 24217                        4.80                    4.80
# 24219                        4.80                    4.80
# 24220                        4.80                    4.80
# 24222                        4.80                    4.80
# 24223                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 0                     4.86                                           3
# 1                     4.84                                           2
# 2                     4.71                                           3
# 3                     4.70                                           1
# 4                     4.48                                           3
# ...                    ...                                         ...
# 24217                 4.70                                           3
# 24219                 4.70                                           2
# 24220                 4.70                                           1
# 24222                 4.70                                          13
# 24223                 4.70                                           2
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                2
# ...                                            ...
# 24217                                            0
# 24219                                            0
# 24220                                            0
# 24222                                            0
# 24223                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.19
# 1                                               0              0.54
# 2                                               0              0.31
# 3                                               0              0.00
# 4                                               0              0.46
# ...                                           ...               ...
# 24217                                           0              0.00
# 24219                                           0              0.00
# 24220                                           0              0.00
# 24222                                           0              0.00
# 24223                                           0              0.00
#
# [15602 rows x 71 columns]
#  Coeficiente de determinación
# 0.0010085753058530766
#  Coeficiente de correlación
# 0.03175807465595288

# %%
pr5=mex[mex['room_type'] == 'Private room']
display(sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=pr5))
Vars_Indep= pr5[['number_of_reviews']]
Var_Dep= pr5['availability_365']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=pr5[['number_of_reviews']])
display(y_pred)
print('\n Agregamos predicciones')
pr5.insert(0, 'Predicciones', y_pred)
display(pr5)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.09364539]),
#  'rank_': 1,
#  'singular_': array([5203.65954966]),
#  'intercept_': 255.47449731231168}
#  Eficiencia del modelo
# 0.001848740094272383
#  Predecimos valores
# array([249.66848285, 255.00627034, 255.00627034, ..., 255.47449731,
#        255.47449731, 255.47449731])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 7        249.668483               https://www.airbnb.com/rooms/61792
# 16       255.006270              https://www.airbnb.com/rooms/760912
# 17       255.006270             https://www.airbnb.com/rooms/2088218
# 18       255.474497             https://www.airbnb.com/rooms/2093036
# 21       255.474497              https://www.airbnb.com/rooms/131610
# ...             ...                                              ...
# 24200    255.474497  https://www.airbnb.com/rooms/856473895554110501
# 24213    255.474497  https://www.airbnb.com/rooms/853707681690048732
# 24215    255.474497  https://www.airbnb.com/rooms/853746847434924262
# 24218    255.474497  https://www.airbnb.com/rooms/853922041242738127
# 24221    255.474497  https://www.airbnb.com/rooms/854225071295768399
#
#       last_scraped       source  \
# 7       30/03/2023  city scrape
# 16      30/03/2023  city scrape
# 17      30/03/2023  city scrape
# 18      29/03/2023  city scrape
# 21      29/03/2023  city scrape
# ...            ...          ...
# 24200   30/03/2023  city scrape
# 24213   30/03/2023  city scrape
# 24215   29/03/2023  city scrape
# 24218   29/03/2023  city scrape
# 24221   29/03/2023  city scrape
#
#                                                   name  \
# 7      Spacious Clean Quiet room (own bath) in Condesa
# 16                 Stylish bachelor pad in La Roma, DF
# 17              Private rooms near old Coyoacan center
# 18                 Departamento 2 dormitorios x Antara
# 21                                      MARIA DEL ALMA
# ...                                                ...
# 24200                                              506
# 24213              Beautiful Sunny bedroom off Masaryk
# 24215   Room with great view & BR 1 block from Reforma
# 24218                  Excelente Ambiente 5570,835,621
# 24221           HabitaciÃ³n privada en magnÃ­fica casa
#
#                                              description  \
# 7      Located in La Condesa, one of the best neighbo...
# 16     <b>The space</b><br />If you are coming to Mex...
# 17     Hello! I have 2 private rooms for rent in a ni...
# 18     Departamento de 2 dormitorios y 1 banos comple...
# 21     <b>The space</b><br />VIVE LA EXPERIENCIA DE C...
# ...                                                  ...
# 24200  " THE BRIT " es un edificio Ãºnico en su clase...
# 24213  This cozy and sunny bedroom is the perfect pla...
# 24215  Private room in Penthouse located in the heart...
# 24218  Tu familia estarÃ¡ cerca de todo si te hospeda...
# 24221  RelÃ¡jate en este espacio muy tranquilo y eleg...
#
#                                    neighborhood_overview  \
# 7      You are going to be in one of the nicest neigh...
# 16                                           Sin vecinos
# 17     Es una zona residencial de CoyoacÃ¡n, ubicada ...
# 18     El apartamento se encuentra en una zona reside...
# 21                                           Sin vecinos
# ...                                                  ...
# 24200                                        Sin vecinos
# 24213  Polanco one of the safest and best neighborhoo...
# 24215  Many restaurant option as well as cafes and ba...
# 24218                                        Sin vecinos
# 24221                                        Sin vecinos
#
#                                              picture_url  \
# 7      https://a0.muscache.com/pictures/4c674e38-42f8...
# 16     https://a0.muscache.com/pictures/10580755/b2dc...
# 17     https://a0.muscache.com/pictures/32395878/54f6...
# 18     https://a0.muscache.com/pictures/28553895/71d5...
# 21     https://a0.muscache.com/pictures/837085/b9ed71...
# ...                                                  ...
# 24200  https://a0.muscache.com/pictures/miso/Hosting-...
# 24213  https://a0.muscache.com/pictures/miso/Hosting-...
# 24215  https://a0.muscache.com/pictures/miso/Hosting-...
# 24218  https://a0.muscache.com/pictures/d2e3ac33-c092...
# 24221  https://a0.muscache.com/pictures/db71951a-8696...
#
#                                           host_url host_name  ...  \
# 7         https://www.airbnb.com/users/show/299558   Roberto  ...
# 16       https://www.airbnb.com/users/show/3817743       Max  ...
# 17      https://www.airbnb.com/users/show/10659485   CÃ©cile  ...
# 18       https://www.airbnb.com/users/show/3083561  Federico  ...
# 21        https://www.airbnb.com/users/show/647454  Fernando  ...
# ...                                            ...       ...  ...
# 24200  https://www.airbnb.com/users/show/505303275      Ivan  ...
# 24213  https://www.airbnb.com/users/show/506768013   Mohamed  ...
# 24215   https://www.airbnb.com/users/show/68325043   Mariana  ...
# 24218  https://www.airbnb.com/users/show/506810572     Angel  ...
# 24221  https://www.airbnb.com/users/show/154670560      Aroa  ...
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 7                       4.89                       4.9                  4.92
# 16                      4.60                       4.2                  5.00
# 17                      5.00                       4.6                  5.00
# 18                      4.80                       4.7                  4.80
# 21                      4.80                       4.7                  4.80
# ...                      ...                       ...                   ...
# 24200                   4.80                       4.7                  4.80
# 24213                   4.80                       4.7                  4.80
# 24215                   4.80                       4.7                  4.80
# 24218                   4.80                       4.7                  4.80
# 24221                   4.80                       4.7                  4.80
#
#       review_scores_communication  review_scores_location  \
# 7                            4.95                    4.94
# 16                           4.60                    4.80
# 17                           4.80                    4.40
# 18                           4.80                    4.80
# 21                           4.80                    4.80
# ...                           ...                     ...
# 24200                        4.80                    4.80
# 24213                        4.80                    4.80
# 24215                        4.80                    4.80
# 24218                        4.80                    4.80
# 24221                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 7                     4.87                                           0
# 16                    4.60                                           0
# 17                    4.40                                           0
# 18                    4.70                                           0
# 21                    4.70                                           1
# ...                    ...                                         ...
# 24200                 4.70                                           1
# 24213                 4.70                                           0
# 24215                 4.70                                           0
# 24218                 4.70                                           0
# 24221                 4.70                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 7                                                2
# 16                                               1
# 17                                               1
# 18                                               1
# 21                                               2
# ...                                            ...
# 24200                                            5
# 24213                                            1
# 24215                                            1
# 24218                                            2
# 24221                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 7                                               0              0.94
# 16                                              0              0.04
# 17                                              0              0.04
# 18                                              0              0.00
# 21                                              0              0.00
# ...                                           ...               ...
# 24200                                           0              0.00
# 24213                                           0              0.00
# 24215                                           0              0.00
# 24218                                           0              0.00
# 24221                                           0              0.00
#
# [8202 rows x 71 columns]
#  Coeficiente de determinación
# 0.001848740094272383
#  Coeficiente de correlación
# 0.04299697773416619

# %% [markdown]
# # **reviews_per_month vs review_scores_communication**

# %%
eha6=mex[mex['room_type'] == 'Entire home/apt']
display(sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=eha6))
Vars_Indep= eha6[['review_scores_communication']]
Var_Dep= eha6['reviews_per_month']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=eha6[['review_scores_communication']])
display(y_pred)
print('\n Agregamos predicciones')
eha6.insert(0, 'Predicciones', y_pred)
display(eha6)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_communication'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.43709298]),
#  'rank_': 1,
#  'singular_': array([40.72587797]),
#  'intercept_': -0.42260129949032077}
#  Eficiencia del modelo
# 0.006494176335523183
#  Predecimos valores
# array([1.74100897, 1.76286361, 1.72789618, ..., 1.67544502, 1.67544502,
#        1.67544502])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 0          1.741009             https://www.airbnb.com/rooms/2056638
# 1          1.762864             https://www.airbnb.com/rooms/2072354
# 2          1.727896              https://www.airbnb.com/rooms/696037
# 3          1.675445               https://www.airbnb.com/rooms/35797
# 4          1.666703               https://www.airbnb.com/rooms/44616
# ...             ...                                              ...
# 24217      1.675445  https://www.airbnb.com/rooms/853790308958785669
# 24219      1.675445  https://www.airbnb.com/rooms/853923589855678923
# 24220      1.675445  https://www.airbnb.com/rooms/853966732274073000
# 24222      1.675445  https://www.airbnb.com/rooms/854247693069190865
# 24223      1.675445  https://www.airbnb.com/rooms/854260329845513725
#
#       last_scraped       source  \
# 0       30/03/2023  city scrape
# 1       30/03/2023  city scrape
# 2       29/03/2023  city scrape
# 3       29/03/2023  city scrape
# 4       30/03/2023  city scrape
# ...            ...          ...
# 24217   29/03/2023  city scrape
# 24219   30/03/2023  city scrape
# 24220   29/03/2023  city scrape
# 24222   30/03/2023  city scrape
# 24223   30/03/2023  city scrape
#
#                                                     name  \
# 0                    Amplio y luminoso loft en CoyoacÃ¡n
# 1                     Coyoacan Historic Studio Apartment
# 2      3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                            Villa Dante
# 4                                      CONDESA HAUS  B&B
# ...                                                  ...
# 24217                                          Cozy Loft
# 24219                              RincÃ³n Mexico lindo!
# 24220                     Departamento en zona diamante.
# 24222                   Espacioso y luminoso loft - Roma
# 24223      Maravilloso departamento en Ciudad de MÃ©xico
#
#                                              description  \
# 0      CÃ³modo loft de dos pisos magnÃ­ficamente ubic...
# 1      This studio flat is adjacent to the owner's ho...
# 2      Beautifully decorated 3 bedroom apartment, it ...
# 3      Dentro de Villa un estudio de arte con futon, ...
# 4      A new concept of hosting in mexico through a b...
# ...                                                  ...
# 24217          Cossy loft en una ubicaciÃ³n estratÃ©gica
# 24219  Este lugar tiene una ubicaciÃ³n estratÃ©gica: ...
# 24220  Ubicado en zona diamante, junto al aeropuerto,...
# 24222  What else does it come with?<br />- WIFI 100MB...
# 24223  Ven a descubrir este increÃ­ble departamento e...
#
#                                    neighborhood_overview  \
# 0                                            Sin vecinos
# 1      Located in Coyoacan, in a quiet neighborhood w...
# 2      This area is called Nuevo Polanco, it has bein...
# 3      Centro comercial Santa Fe, parque interlomas y...
# 4                                            Sin vecinos
# ...                                                  ...
# 24217                       En el corazÃ³n de la Condesa
# 24219                                        Sin vecinos
# 24220                                        Sin vecinos
# 24222                                        Sin vecinos
# 24223  Una zona muy bonita ya que varias de las atrac...
#
#                                              picture_url  \
# 0      https://a0.muscache.com/pictures/28353712/4379...
# 1      https://a0.muscache.com/pictures/369f3371-593a...
# 2      https://a0.muscache.com/pictures/10960397/67b2...
# 3      https://a0.muscache.com/pictures/f395ab78-1185...
# 4      https://a0.muscache.com/pictures/251410/ec75fe...
# ...                                                  ...
# 24217  https://a0.muscache.com/pictures/miso/Hosting-...
# 24219  https://a0.muscache.com/pictures/miso/Hosting-...
# 24220  https://a0.muscache.com/pictures/miso/Hosting-...
# 24222  https://a0.muscache.com/pictures/miso/Hosting-...
# 24223  https://a0.muscache.com/pictures/miso/Hosting-...
#
#                                           host_url  \
# 0       https://www.airbnb.com/users/show/10531228
# 1       https://www.airbnb.com/users/show/16840050
# 2        https://www.airbnb.com/users/show/3531879
# 3         https://www.airbnb.com/users/show/153786
# 4         https://www.airbnb.com/users/show/196253
# ...                                            ...
# 24217   https://www.airbnb.com/users/show/29239005
# 24219  https://www.airbnb.com/users/show/488030249
# 24220  https://www.airbnb.com/users/show/506816029
# 24222    https://www.airbnb.com/users/show/7799414
# 24223  https://www.airbnb.com/users/show/506864314
#
#                                 host_name  ... review_scores_accuracy  \
# 0                                   Maria  ...                   4.71
# 1                                 MÃ³nica  ...                   4.90
# 2                        Gonzalo & Sandra  ...                   4.82
# 3                                    Dici  ...                   4.80
# 4      Condesa Haus Bed & Breakfast  CDMX  ...                   4.56
# ...                                   ...  ...                    ...
# 24217                                 Sol  ...                   4.80
# 24219                                 Ana  ...                   4.80
# 24220                   Jacqueline Vivian  ...                   4.80
# 24222                               Tiane  ...                   4.80
# 24223                         Empresarial  ...                   4.80
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.95                  5.00
# 1                          4.88                  4.93
# 2                          4.71                  4.92
# 3                          4.70                  4.80
# 4                          4.70                  4.87
# ...                         ...                   ...
# 24217                      4.70                  4.80
# 24219                      4.70                  4.80
# 24220                      4.70                  4.80
# 24222                      4.70                  4.80
# 24223                      4.70                  4.80
#
#       review_scores_communication  review_scores_location  \
# 0                            4.95                    5.00
# 1                            5.00                    4.95
# 2                            4.92                    4.58
# 3                            4.80                    4.80
# 4                            4.78                    4.98
# ...                           ...                     ...
# 24217                        4.80                    4.80
# 24219                        4.80                    4.80
# 24220                        4.80                    4.80
# 24222                        4.80                    4.80
# 24223                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 0                     4.86                                           3
# 1                     4.84                                           2
# 2                     4.71                                           3
# 3                     4.70                                           1
# 4                     4.48                                           3
# ...                    ...                                         ...
# 24217                 4.70                                           3
# 24219                 4.70                                           2
# 24220                 4.70                                           1
# 24222                 4.70                                          13
# 24223                 4.70                                           2
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                2
# ...                                            ...
# 24217                                            0
# 24219                                            0
# 24220                                            0
# 24222                                            0
# 24223                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.19
# 1                                               0              0.54
# 2                                               0              0.31
# 3                                               0              0.00
# 4                                               0              0.46
# ...                                           ...               ...
# 24217                                           0              0.00
# 24219                                           0              0.00
# 24220                                           0              0.00
# 24222                                           0              0.00
# 24223                                           0              0.00
#
# [15602 rows x 71 columns]
#  Coeficiente de determinación
# 0.006494176335523183
#  Coeficiente de correlación
# 0.08058645255576885

# %%
pr6=mex[mex['room_type'] == 'Private room']
display(sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=pr6))
Vars_Indep= pr6[['review_scores_communication']]
Var_Dep= pr6['reviews_per_month']
model= LinearRegression()
type(model)
model.fit(X=Vars_Indep, y=Var_Dep)
print('\n Predicción de modelo')
display(model.__dict__)
print('\n Eficiencia del modelo')
display(model.score(Vars_Indep,Var_Dep))
print('\n Predecimos valores')
y_pred= model.predict(X=pr6[['review_scores_communication']])
display(y_pred)
print('\n Agregamos predicciones')
pr6.insert(0, 'Predicciones', y_pred)
display(pr6)
print('\n Coeficiente de determinación')
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
display(coef_Deter)
print('\n Coeficiente de correlación')
coef_Correl=np.sqrt(coef_Deter)
display(coef_Correl)
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>
#  Predicción de modelo
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_communication'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.14311043]),
#  'rank_': 1,
#  'singular_': array([43.06525823]),
#  'intercept_': 0.3572689175302334}
#  Eficiencia del modelo
# 0.001197232570863016
#  Predecimos valores
# array([1.06566555, 1.0155769 , 1.04419899, ..., 1.04419899, 1.04419899,
#        1.04419899])
#  Agregamos predicciones
#        Predicciones                                      listing_url  \
# 7          1.065666               https://www.airbnb.com/rooms/61792
# 16         1.015577              https://www.airbnb.com/rooms/760912
# 17         1.044199             https://www.airbnb.com/rooms/2088218
# 18         1.044199             https://www.airbnb.com/rooms/2093036
# 21         1.044199              https://www.airbnb.com/rooms/131610
# ...             ...                                              ...
# 24200      1.044199  https://www.airbnb.com/rooms/856473895554110501
# 24213      1.044199  https://www.airbnb.com/rooms/853707681690048732
# 24215      1.044199  https://www.airbnb.com/rooms/853746847434924262
# 24218      1.044199  https://www.airbnb.com/rooms/853922041242738127
# 24221      1.044199  https://www.airbnb.com/rooms/854225071295768399
#
#       last_scraped       source  \
# 7       30/03/2023  city scrape
# 16      30/03/2023  city scrape
# 17      30/03/2023  city scrape
# 18      29/03/2023  city scrape
# 21      29/03/2023  city scrape
# ...            ...          ...
# 24200   30/03/2023  city scrape
# 24213   30/03/2023  city scrape
# 24215   29/03/2023  city scrape
# 24218   29/03/2023  city scrape
# 24221   29/03/2023  city scrape
#
#                                                   name  \
# 7      Spacious Clean Quiet room (own bath) in Condesa
# 16                 Stylish bachelor pad in La Roma, DF
# 17              Private rooms near old Coyoacan center
# 18                 Departamento 2 dormitorios x Antara
# 21                                      MARIA DEL ALMA
# ...                                                ...
# 24200                                              506
# 24213              Beautiful Sunny bedroom off Masaryk
# 24215   Room with great view & BR 1 block from Reforma
# 24218                  Excelente Ambiente 5570,835,621
# 24221           HabitaciÃ³n privada en magnÃ­fica casa
#
#                                              description  \
# 7      Located in La Condesa, one of the best neighbo...
# 16     <b>The space</b><br />If you are coming to Mex...
# 17     Hello! I have 2 private rooms for rent in a ni...
# 18     Departamento de 2 dormitorios y 1 banos comple...
# 21     <b>The space</b><br />VIVE LA EXPERIENCIA DE C...
# ...                                                  ...
# 24200  " THE BRIT " es un edificio Ãºnico en su clase...
# 24213  This cozy and sunny bedroom is the perfect pla...
# 24215  Private room in Penthouse located in the heart...
# 24218  Tu familia estarÃ¡ cerca de todo si te hospeda...
# 24221  RelÃ¡jate en este espacio muy tranquilo y eleg...
#
#                                    neighborhood_overview  \
# 7      You are going to be in one of the nicest neigh...
# 16                                           Sin vecinos
# 17     Es una zona residencial de CoyoacÃ¡n, ubicada ...
# 18     El apartamento se encuentra en una zona reside...
# 21                                           Sin vecinos
# ...                                                  ...
# 24200                                        Sin vecinos
# 24213  Polanco one of the safest and best neighborhoo...
# 24215  Many restaurant option as well as cafes and ba...
# 24218                                        Sin vecinos
# 24221                                        Sin vecinos
#
#                                              picture_url  \
# 7      https://a0.muscache.com/pictures/4c674e38-42f8...
# 16     https://a0.muscache.com/pictures/10580755/b2dc...
# 17     https://a0.muscache.com/pictures/32395878/54f6...
# 18     https://a0.muscache.com/pictures/28553895/71d5...
# 21     https://a0.muscache.com/pictures/837085/b9ed71...
# ...                                                  ...
# 24200  https://a0.muscache.com/pictures/miso/Hosting-...
# 24213  https://a0.muscache.com/pictures/miso/Hosting-...
# 24215  https://a0.muscache.com/pictures/miso/Hosting-...
# 24218  https://a0.muscache.com/pictures/d2e3ac33-c092...
# 24221  https://a0.muscache.com/pictures/db71951a-8696...
#
#                                           host_url host_name  ...  \
# 7         https://www.airbnb.com/users/show/299558   Roberto  ...
# 16       https://www.airbnb.com/users/show/3817743       Max  ...
# 17      https://www.airbnb.com/users/show/10659485   CÃ©cile  ...
# 18       https://www.airbnb.com/users/show/3083561  Federico  ...
# 21        https://www.airbnb.com/users/show/647454  Fernando  ...
# ...                                            ...       ...  ...
# 24200  https://www.airbnb.com/users/show/505303275      Ivan  ...
# 24213  https://www.airbnb.com/users/show/506768013   Mohamed  ...
# 24215   https://www.airbnb.com/users/show/68325043   Mariana  ...
# 24218  https://www.airbnb.com/users/show/506810572     Angel  ...
# 24221  https://www.airbnb.com/users/show/154670560      Aroa  ...
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 7                       4.89                       4.9                  4.92
# 16                      4.60                       4.2                  5.00
# 17                      5.00                       4.6                  5.00
# 18                      4.80                       4.7                  4.80
# 21                      4.80                       4.7                  4.80
# ...                      ...                       ...                   ...
# 24200                   4.80                       4.7                  4.80
# 24213                   4.80                       4.7                  4.80
# 24215                   4.80                       4.7                  4.80
# 24218                   4.80                       4.7                  4.80
# 24221                   4.80                       4.7                  4.80
#
#       review_scores_communication  review_scores_location  \
# 7                            4.95                    4.94
# 16                           4.60                    4.80
# 17                           4.80                    4.40
# 18                           4.80                    4.80
# 21                           4.80                    4.80
# ...                           ...                     ...
# 24200                        4.80                    4.80
# 24213                        4.80                    4.80
# 24215                        4.80                    4.80
# 24218                        4.80                    4.80
# 24221                        4.80                    4.80
#
#        review_scores_value calculated_host_listings_count_entire_homes  \
# 7                     4.87                                           0
# 16                    4.60                                           0
# 17                    4.40                                           0
# 18                    4.70                                           0
# 21                    4.70                                           1
# ...                    ...                                         ...
# 24200                 4.70                                           1
# 24213                 4.70                                           0
# 24215                 4.70                                           0
# 24218                 4.70                                           0
# 24221                 4.70                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 7                                                2
# 16                                               1
# 17                                               1
# 18                                               1
# 21                                               2
# ...                                            ...
# 24200                                            5
# 24213                                            1
# 24215                                            1
# 24218                                            2
# 24221                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 7                                               0              0.94
# 16                                              0              0.04
# 17                                              0              0.04
# 18                                              0              0.00
# 21                                              0              0.00
# ...                                           ...               ...
# 24200                                           0              0.00
# 24213                                           0              0.00
# 24215                                           0              0.00
# 24218                                           0              0.00
# 24221                                           0              0.00
#
# [8202 rows x 71 columns]
#  Coeficiente de determinación
# 0.001197232570863016
#  Coeficiente de correlación
# 0.03460104869600076
